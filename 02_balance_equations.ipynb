# %% [markdown]
# # Balance reaction mass and charge

# %% [markdown]
# ### Find reactions that have unbalanced charges, and add charges or protons etc. as necessary to repair.

# %% [markdown]
# Use list of unbalanced reactions with R functions in "investigate_metabolite_charges.r"
#
# ### TO DO: handle exchange reactions separately
#
# Example scripts that include addressing unbalanced reactions:
# https://github.com/ChristianLieven/memote-m-capsulatus/blob/master/ComplementaryScripts/12.%20ApplyMemoteDrivenCuration.ipynb
# https://github.com/SysBioChalmers/Sco-GEM/blob/devel/code/curation/v1_3_2.py
# https://github.com/SBRG/bigg_models/blob/master/bigg_models/tests/test_loaded_data.py
# This process is especially relevant for carveme models: https://github.com/cdanielmachado/carveme/issues/136
#
# Could also use alongside custom reaction databases:  https://github.com/SysBioChalmers/Salb-GEM/tree/master/ComplementaryData/curation

# %% [markdown]
# Import libraries, read in SBML v3 model

# %%
import cobra
import os
import numpy as np
import pandas as pd
import memote.support.consistency as consistency
import memote.support.consistency_helpers as con_helpers
from memote.utils import annotate, get_ids, truncate, wrapper
from six import iteritems, itervalues
from collections import defaultdict
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
model_in = cobra.io.read_sbml_model('/projectnb2/talbot-lab-data/metabolic_models/genomes/solibacter/solibacter.xml')

# %% [markdown]
# Identify problematic reactions and their metaNET listings from annotations (https://github.com/opencobra/cobrapy/issues/684)

# %%
#rxn_list = consistency.find_mass_unbalanced_reactions(model_in.reactions)
rxn_list = consistency.find_charge_unbalanced_reactions(model_in.reactions) # handle mass & charge simultaneously?
#print(rxn_list)
print(rxn_list[0:10])
# Out:
# [<Reaction 2AGPGAT160 at 0x2af964ee8390>, <Reaction 2AGPGAT161 at 0x2af964ee3f28>, <Reaction 2DDARAA at 0x2af964ee8f60>, <Reaction 2MBALDH at 0x2af964ee7940>, <Reaction 2S6HCCi at 0x2af964ee7b70>, <Reaction 3HAACOAT80 at 0x2af964ee7fd0>, <Reaction A6PAG at 0x2af964f01860>, <Reaction AACPS2 at 0x2af964f06b70>, <Reaction AACPS4 at 0x2af964f0b0f0>, <Reaction AACPS7 at 0x2af964f0b390>]

# %% [markdown]
# ## Fix mass and charge balances for each reaction

# %% [markdown]
# ### Example 1 (testing)

# %%
#for rxn in rxn_list:
rxn = rxn_list[0]
rxn.check_mass_balance()
# Print metanetxID if exists
metanetx_id = rxn.annotation['metanetx.reaction']
print(metanetx_id)
print(rxn)

charge = 0
for metabolite, coefficient in iteritems(rxn.metabolites):
    print(metabolite)
    print(metabolite.charge)
    charge += coefficient * metabolite.charge
# Out:
# {'charge': 1.0}
# MNXR94774
# 2AGPGAT160: 2agpg160_c + atp_c + hdca_c --> amp_c + pg160_c + ppi_c
# 2agpg160_c
# -1
# atp_c
# -4
# hdca_c
# -1
# amp_c
# -2
# pg160_c
# 0
# ppi_c
# -3

# %% [markdown]
# Compare this reaction against the output from R script:
# Check with R script:
# ```
# get_bigg_charges(metanetxID = "MNXR94774",
# reference_data = ref_data)
# ```
#
# ```
# MetanetX has the following charges on left of equation:
#     hdca        h 2agpg160      atp
#       -1        1       -1       -4
# MetanetX has the following charges on right of equation:
#   ppi   amp pg160
#    -3    -2     0
#    ```
#  We see that adding a proton to the left side of the equation would balance it mass-wise, but unbalance the charge, so we need a different solution:

# %%
rxn.add_metabolites({model_in.metabolites.h_c:-1}, combine= True)
rxn.check_mass_balance()

#model_in.reactions.2AGPGAT160.add_metabolites({model.model_in.h_p:1}, combine= True)
# Out:
# {'H': -1.0}

# %% [markdown]
# ### Example 2 (testing)

# %%
#for rxn in rxn_list:
rxn = model_in.reactions.get_by_id('A6PAG')
rxn.annotation

rxn.check_mass_balance()

print(rxn)

charge = 0
for metabolite, coefficient in iteritems(rxn.metabolites):
    print(metabolite)
    print(metabolite.charge)
    charge += coefficient * metabolite.charge
# Out:
# {'sbo': 'SBO:0000176'}
# {'charge': 2.0}
# A6PAG: atp_c + gal_c --> adp_c + dgal6p_c + h_c
# atp_c
# -4
# gal_c
# 0
# adp_c
# -3
# dgal6p_c
# 0
# h_c
# 1

# %% [markdown]
# Check with R script:
# ```
# get_bigg_charges(metanetxID = NULL,
# biggID = "A6PAG",
# reference_data = ref_data)
# ```
# MetanetX has the following charges on left of equation:
#  adp <NA>
#    0   -3
# MetanetX has the following charges on right of equation:
# gal   h atp
#   0   1  -4
#
# For some reason, metabolite ID "MNXM1103987" doesn't have its BiGG ID listed within the chem_xref.tsv file.

# %%
model_in.metabolites.pg160_c.charge = -1
#model_in.metabolites.2ddara_c.charge = -1
rxn.metabolites

for metabolite, coefficient in iteritems(rxn.metabolites):
    rxn.metabolites.gcald_c.charge
    
rxn.check_mass_balance()
# Out:
# {<Metabolite 2ddara_c at 0x2b4d9e53f7f0>: -1.0,
#  <Metabolite gcald_c at 0x2b4d9e767898>: 1.0,
#  <Metabolite pyr_c at 0x2b4d9e9595f8>: 1.0}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-5b17f504cbd7> in <module>()
#       4
#       5 for metabolite, coefficient in iteritems(rxn.metabolites):
# ----> 6     rxn.metabolites.gcald_c.charge
#       7
#       8 rxn.check_mass_balance()
#
# AttributeError: 'dict' object has no attribute 'gcald_c'

# %% [markdown]
# ### Run loop on all reactions

# %% [markdown]
# Apply to all problematic reactions and evaluate success

# %%
for rxn in rxn_list:
    print(rxn)
    #charge = model_in.reactions.rxn.check_mass_balance()
    #print(charge)

    charge = 0
    for metabolite, coefficient in iteritems(rxn.metabolites):
        charge += coefficient * metabolite.charge
    print(charge)
    print(con_helpers.is_charge_balanced(rxn))
    #model.reactions.PAMMOipp.add_metabolites({model.metabolites.h_p:1}, combine= True)
# Out:
# 2AGPGAT160: 2agpg160_c + atp_c + hdca_c --> amp_c + pg160_c + ppi_c
# 1.0
# False
# 2AGPGAT161: 2agpg161_c + atp_c + hdcea_c --> amp_c + pg161_c + ppi_c
# -1.0
# False
# 2DDARAA: 2ddara_c <=> gcald_c + pyr_c
# -1.0
# False
# 2MBALDH: 2mbald_c + h2o_c + nad_c <=> 2mba_c + 2.0 h_c + nadh_c
# 1.0
# False
# 2S6HCCi: akg_c + h_c + ichor_c <=> 2shchc_c + co2_c + pyr_c
# 2.0
# False
# 3HAACOAT80: 3hoctACP_c + coa_c <=> ACP_c + R_3hocoa_c
# 6.0
# False
# A6PAG: atp_c + gal_c --> adp_c + dgal6p_c + h_c
# 2.0
# False
# AACPS2: ACP_c + atp_c + ttdcea_c --> amp_c + ppi_c + tdeACP_c
# -2.0
# False
# AACPS4: ACP_c + atp_c + hdcea_c --> amp_c + hdeACP_c + ppi_c
# -2.0
# False
# AACPS7: ACP_c + atp_c + ddca_c --> amp_c + ddcaACP_c + ppi_c
# -1.0
# False
# AACPS9: ACP_c + atp_c + octa_c --> amp_c + ocACP_c + ppi_c
# -2.0
# False
# AALDH: nadh_c + pacald_c <=> nad_c + pea_c
# 1.0
# False
# ACACT5r_1: accoa_c + dccoa_c <=> 3oddcoa_c + coa_c
# -4.0
# False
# ACACT6r_1: accoa_c + ddcoa_c <=> 3otdcoa_c + coa_c
# -4.0
# False
# ACGAMPM: acgam6p_c <=> acgam1p_c
# 2.0
# False
# ACHBS: 2obut_c + h_c + pyr_c --> 2ahbut_c + co2_c
# 1.0
# False
# ACKILE: 2mb_p_c + adp_c --> 2mba_c + atp_c
# -1.0
# False
# ACLS_a: h_c + pyr_c + thmpp_c --> co2_c + hethmpp_c
# 2.0
# False
# ACLS_b: alac__S_c + thmpp_c <=> hethmpp_c + pyr_c
# 2.0
# False
# ACLS_d: hethmpp_c + lpam_c <=> adhlam_c + thmpp_c
# -2.0
# False
# ACLSa_1: 2.0 h_c + pyr_c + thmpp_c --> 2hetdp_c + co2_c
# 1.0
# False
# ACLSb_1: 2hetdp_c + pyr_c --> alac__S_c + h_c + thmpp_c
# -1.0
# False
# ACM6PH: acmum6p_c + h2o_c --> acgam6p_c + lac__D_c
# -3.0
# False
# ACOAD3: nad_c + occoa_c <=> h_c + nadh_c + oc2coa_c
# 4.0
# False
# ACOAD3f: fad_c + occoa_c <=> fadh2_c + oc2coa_c
# 4.0
# False
# ACOAD4_1: dccoa_c + nad_c <=> dc2coa_c + h_c + nadh_c
# -4.0
# False
# ACOAD6: nad_c + tdcoa_c <=> h_c + nadh_c + td2coa_c
# 4.0
# False
# ACOAD6f: fad_c + tdcoa_c <=> fadh2_c + td2coa_c
# 4.0
# False
# ACP1_FMN: fmn_c + h2o_c --> pi_c + ribflv_c
# -2.0
# False
# ACPPAT120: ddcaACP_c + h_c + pi_c --> ACP_c + ddcap_c
# 2.0
# False
# ACPPAT141: h_c + pi_c + tdeACP_c --> ACP_c + ttdceap_c
# 3.0
# False
# ACPPAT161: h_c + hdeACP_c + pi_c --> ACP_c + hdceap_c
# 3.0
# False
# ACSERHS: acser_c + trdrd_c + tsul_c --> ac_c + cys__L_c + h_c + so3_c + trdox_c
# -2.0
# False
# ACSERL: acser_c + seln_c --> ac_c + selcys_c
# -1.0
# False
# ACSPHAC100: R_3hdcaa_c + atp_c + coa_c --> R_3hdcoa_c + amp_c + ppi_c
# 3.0
# False
# ACSPHAC101: R3hdec4e_c + atp_c + coa_c --> R3hdec4coa_c + amp_c + ppi_c
# 3.0
# False
# ACSPHAC120: R_3hdda_c + atp_c + coa_c --> R_3hddcoa_c + amp_c + ppi_c
# -1.0
# False
# ACSPHAC121: R_3hdd5ea_c + atp_c + coa_c --> R_3hcddec5ecoa_c + amp_c + ppi_c
# 3.0
# False
# ACSPHAC121d6: R_3hdd6e_c + atp_c + coa_c --> R_3hdd6coa_c + amp_c + ppi_c
# 3.0
# False
# ACSPHAC140: R_3httdca_c + atp_c + coa_c --> R_3hmrscoa_c + amp_c + ppi_c
# -1.0
# False
# ACSPHAC141: R_3hcmrs7e_c + atp_c + coa_c --> R_3hcmrs7ecoa_c + amp_c + ppi_c
# 3.0
# False
# ACSPHAC141d5: R_3htd5e_c + atp_c + coa_c --> R_3htd5coa_c + amp_c + ppi_c
# 3.0
# False
# ACSPHAC142: R_3htd58e_c + atp_c + coa_c --> R_3htd58coa_c + amp_c + ppi_c
# 3.0
# False
# ACSPHAC160: R_3hhdca_c + atp_c + coa_c --> R_3hhdcoa_c + amp_c + ppi_c
# 3.0
# False
# ACSPHAC40: atp_c + bhb_c + coa_c --> 3hbcoa__R_c + amp_c + ppi_c
# 4.0
# False
# ACSPHAC50: R_3hpt_c + atp_c + coa_c --> R_3hptcoa_c + amp_c + ppi_c
# 3.0
# False
# ACSPHAC60: R_3hhxa_c + atp_c + coa_c --> R_3hhcoa_c + amp_c + ppi_c
# 3.0
# False
# ACSPHAC70: R_3hhpa_c + atp_c + coa_c --> R_3hhpcoa_c + amp_c + ppi_c
# 3.0
# False
# ACSPHAC80: R_3hocta_c + atp_c + coa_c --> R_3hocoa_c + amp_c + ppi_c
# 3.0
# False
# ACSPHAC90: R_3hnonaa_c + atp_c + coa_c --> R_3hnonacoa_c + amp_c + ppi_c
# 3.0
# False
# ADK2: amp_c + pppi_c <=> adp_c + ppi_c
# -4.0
# False
# ADK2_1: amp_c + pppi_c <=> adp_c + ppi_c
# -4.0
# False
# ADMDC: amet_c + h_c --> ametam_c + co2_c
# -2.0
# False
# ADPRDP: adprib_c + h2o_c --> amp_c + 2.0 h_c + r5p_c
# 2.0
# False
# ADPRDP_1: adprib_c + h2o_c --> amp_c + 2.0 h_c + r5p_c
# 2.0
# False
# ADSELK: adsel_c + atp_c --> 3padsel_c + adp_c + h_c
# 2.0
# False
# ADSELR: 3padsel_c + trdrd_c --> 2.0 h_c + pap_c + slnt_c + trdox_c
# -4.0
# False
# ADSL1r: dcamp_c <=> amp_c + fum_c
# -4.0
# False
# ADSS: asp__L_c + gtp_c + imp_c --> dcamp_c + gdp_c + 2.0 h_c + pi_c
# 4.0
# False
# AGM3PA: anhgm3p_c + h2o_c --> LalaDgluMdap_c + anhgm_c
# -2.0
# False
# AGM3PApp: anhgm3p_p + h2o_p --> LalaDgluMdap_p + anhgm_p
# -2.0
# False
# AGM3PH: anhgm3p_c + h2o_c --> acgam_c + anhm3p_c
# -2.0
# False
# AGM4PCPpp: anhgm4p_p + h2o_p --> ala__D_p + anhgm3p_p
# 2.0
# False
# AGPAT120: 1ddecg3p_c + ddcaACP_c --> ACP_c + pa120_c
# 3.0
# False
# AGPAT141: 1tdec7eg3p_c + tdeACP_c --> ACP_c + pa141_c
# 4.0
# False
# AGPAT161: 1hdec9eg3p_c + hdeACP_c --> ACP_c + pa161_c
# 2.0
# False
# AHGDx: S2hglut_c + nad_c <=> akg_c + h_c + nadh_c
# -2.0
# False
# AHMMPDPT: 4a2mpmpmd_c + atp_c --> 2mahmp_c + adp_c + h_c
# -1.0
# False
# AHMMPS: air_c + 2.0 h_c --> 4ahmmp_c + gcald_c + pi_c
# -4.0
# False
# AHMMPS2: air_c + amet_c --> 4a2mpmpmd_c + co_c + dad_5_c + for_c + h_c + met__L_c
# -1.0
# False
# AHMMPS_1: air_c + h2o_c --> 4ahmmp_c + gcald_c + 0.5 o2_c + pi_c
# -2.0
# False
# AHSERL4: acser_c + trdrd_c + tsul_c --> ac_c + cys__L_c + h_c + so3_c + trdox_c
# -2.0
# False
# AIRC1: air_c + atp_c + co2_c + h2o_c --> 5aizc_c + adp_c + 2.0 h_c + pi_c
# 1.0
# False
# AIRC2: air_c + atp_c + hco3_c --> 5caiz_c + adp_c + h_c + pi_c
# -2.0
# False
# AIRC3: 5aizc_c <=> 5caiz_c
# -3.0
# False
# AIRCr: air_c + co2_c <=> 5aizc_c + h_c
# 1.0
# False
# AKGDa: akg_c + h_c + lpam_c <=> co2_c + sdhlam_c
# 1.0
# False
# AKGDb: coa_c + sdhlam_c --> dhlam_c + succoa_c
# -1.0
# False
# ALCDpp: etoh_p + pqq_p --> acald_p + pqqh2_p
# -4.0
# False
# ALDD4x: h2o_c + mmalsa__S_c + nad_c --> 2.0 h_c + mmal_c + nadh_c
# -1.0
# False
# ALMPC: amet_c + pc1_c --> ahcys_c + dscl_c + 8.0 h_c
# 7.0
# False
# AMMQT8: 2dmmq8_c + amet_c + h_c --> ahcys_c + mql8_c
# -2.0
# False
# AMPEP10: gly_asp__L_c + h2o_c <=> asp__L_c + gly_c
# -1.0
# False
# AMPEP11: gly_pro__L_c + h2o_c --> gly_c + h_c + pro__L_c
# 1.0
# False
# AMPEP14: h2o_c + h_c + met_L_ala__L_c <=> ala__L_c + met__L_c
# -1.0
# False
# AMPEP15: h2o_c + prohisglu_c --> glu__L_c + his__L_c + pro__L_c
# -1.0
# False
# AMPEP18: h2o_c + serglugly_c --> glu__L_c + gly_c + ser__L_c
# -1.0
# False
# AMPEP5: ala_L_glu__L_c + h2o_c <=> ala__L_c + glu__L_c
# -1.0
# False
# AMPEP8: gly_glu__L_c + h2o_c <=> glu__L_c + gly_c
# -1.0
# False
# AMPMS2: air_c + h2o_c + nad_c --> 4ampm_c + 2.0 for_c + 3.0 h_c + nadh_c
# -2.0
# False
# ANHMK: anhm_c + atp_c + h2o_c --> acmum6p_c + adp_c + h_c
# 3.0
# False
# APG3PAT120: ddcap_c + glyc3p_c --> 1ddecg3p_c + h_c + pi_c
# -1.0
# False
# APG3PAT141: glyc3p_c + ttdceap_c --> 1tdec7eg3p_c + h_c + pi_c
# -1.0
# False
# APG3PAT161: glyc3p_c + hdceap_c --> 1hdec9eg3p_c + h_c + pi_c
# 1.0
# False
# APH120: ddcap_c + h2o_c --> ddca_c + 2.0 h_c + pi_c
# -1.0
# False
# APH141: h2o_c + ttdceap_c --> 2.0 h_c + pi_c + ttdcea_c
# -1.0
# False
# APH161: h2o_c + hdceap_c --> 2.0 h_c + hdcea_c + pi_c
# -1.0
# False
# ARGSL: argsuc_c <=> arg__L_c + fum_c
# -1.0
# False
# ARGSS: asp__L_c + atp_c + citr__L_c --> amp_c + argsuc_c + h_c + ppi_c
# 1.0
# False
# ATPPRT: atp_c + prpp_c --> ppi_c + prbatp_c
# 6.0
# False
# AT_MBD2: dhlam_c + ibcoa_c <=> 2mpdhl_c + coa_c + h_c
# 1.0
# False
# BKDA2: 3mob_c + lpam_c --> 2mpdhl_c + co2_c
# 1.0
# False
# BUP: 3uib_c + h2o_c + 2.0 h_c --> 3aib_c + co2_c + nh4_c
# -1.0
# False
# CCPpp: 2.0 focytc_c + h2o2_p --> 2.0 ficytc_c + 2.0 h2o_p
# -4.0
# False
# CD6P: ctp_c + f6p_c --> cdp_c + fdp_c + h_c
# 4.0
# False
# CDAPPA120: cdpdddecg_c + h2o_c --> cmp_c + 2.0 h_c + pa120_c
# 2.0
# False
# CDAPPA140: cdpdtdecg_c + h2o_c --> cmp_c + 2.0 h_c + pa140_c
# 2.0
# False
# CDAPPA141: cdpdtdec7eg_c + h2o_c --> cmp_c + 2.0 h_c + pa141_c
# 2.0
# False
# CDAPPA161: cdpdhdec9eg_c + h2o_c --> cmp_c + 2.0 h_c + pa161_c
# 2.0
# False
# CDAPPA180: cdpdodecg_c + h2o_c --> cmp_c + 2.0 h_c + pa180_c
# 2.0
# False
# CDAPPA181: cdpdodec11eg_c + h2o_c --> cmp_c + 2.0 h_c + pa181_c
# 2.0
# False
# CDGUNPD: cdigmp_c + h2o_c --> 5pg35pg_c + h_c
# -2.0
# False
# CHORM: chor_c --> pphn_c
# 2.0
# False
# CLPNH120pp: clpn120_p + h2o_p --> h_p + pa120_p + pg120_p
# 3.0
# False
# CLPNH140pp: clpn140_p + h2o_p --> h_p + pa140_p + pg140_p
# 2.0
# False
# CLPNH141pp: clpn141_p + h2o_p --> h_p + pa141_p + pg141_p
# 2.0
# False
# CLPNH160pp: clpn160_p + h2o_p --> h_p + pa160_p + pg160_p
# 1.0
# False
# CLPNH161pp: clpn161_p + h2o_p --> h_p + pa161_p + pg161_p
# 2.0
# False
# CLPNH180pp: clpn180_p + h2o_p --> h_p + pa180_p + pg180_p
# 3.0
# False
# CLPNH181pp: clpn181_p + h2o_p --> h_p + pa181_p + pg181_p
# 2.0
# False
# CLPNS120pp: 2.0 pg120_p <=> clpn120_p + glyc_p
# -2.0
# False
# CLPNS160pp: 2.0 pg160_p <=> clpn160_p + glyc_p
# -2.0
# False
# CLPNS180pp: 2.0 pg180_p <=> clpn180_p + glyc_p
# -2.0
# False
# CMCBTFR1: fadh2_c + 2.0 fcmcbtt_c --> 2.0 cmcbtt_c + fad_c + 2.0 fe2_c + 4.0 h_c
# 8.0
# False
# CMLDC: 4cml_c + h_c --> 5odhf2a_c + co2_c
# -2.0
# False
# CO2FO: co2_c + fdxrd_c + 2.0 h_c <-- co_c + fdxo_2_2_c + h2o_c
# -1.0
# False
# CPP3O1: cpppg3_c + fad_c --> cpp3_c + fadh2_c
# 4.0
# False
# CT6PT: ctp_c + tag6p__D_c --> cdp_c + h_c + tagdp__D_c
# 2.0
# False
# CYO1b: 2.0 focytc_c + 0.5 o2_c --> 2.0 ficytc_c + h2o_c
# -4.0
# False
# CYO4pp: 2.0 ficytc_c + pqqh2_p --> 2.0 focytc_c + pqq_p
# 8.0
# False
# CYTCAA3pp: 2.0 focytc_c + 2.0 h_c + 0.5 o2_c --> 2.0 ficytc_c + h2o_c + 2.0 h_p
# -4.0
# False
# CYTCBB3pp: 2.0 focytc_c + h_c + 0.5 o2_c --> 2.0 ficytc_c + h2o_c + h_p
# -4.0
# False
# D5KGK: atp_c + d5kg_c --> adp_c + d5kgp_c + h_c
# 3.0
# False
# D5KGPA: d5kgp_c --> dhap_c + msa_c
# -3.0
# False
# DACL: abg4_c + h2o_c + h_c <=> 4abz_c + glu__D_c
# -3.0
# False
# DAGK120: 12dgr120_c + atp_c --> adp_c + h_c + pa120_c
# 2.0
# False
# DAGK140: 12dgr140_c + atp_c --> adp_c + h_c + pa140_c
# 2.0
# False
# DAGK141: 12dgr141_c + atp_c --> adp_c + h_c + pa141_c
# 2.0
# False
# DAGK161: 12dgr161_c + atp_c --> adp_c + h_c + pa161_c
# 2.0
# False
# DAGK180: 12dgr180_c + atp_c --> adp_c + h_c + pa180_c
# 2.0
# False
# DAGK181: 12dgr181_c + atp_c --> adp_c + h_c + pa181_c
# 2.0
# False
# DASYN120: ctp_c + h_c + pa120_c --> cdpdddecg_c + ppi_c
# -2.0
# False
# DASYN140: ctp_c + h_c + pa140_c --> cdpdtdecg_c + ppi_c
# -2.0
# False
# DASYN141: ctp_c + h_c + pa141_c --> cdpdtdec7eg_c + ppi_c
# -2.0
# False
# DASYN161: ctp_c + h_c + pa161_c --> cdpdhdec9eg_c + ppi_c
# -2.0
# False
# DASYN180: ctp_c + h_c + pa180_c --> cdpdodecg_c + ppi_c
# -2.0
# False
# DASYN181: ctp_c + h_c + pa181_c --> cdpdodec11eg_c + ppi_c
# -2.0
# False
# DB4PS: ru5p__D_c --> db4p_c + for_c
# 1.0
# False
# DDPGALA: 2dh3dgal6p_c <=> g3p_c + pyr_c
# 2.0
# False
# DGUNC: 2.0 gtp_c --> cdigmp_c + 2.0 ppi_c
# 2.0
# False
# DHBD: 23ddhb_c + nad_c <=> 23dhb_c + h_c + nadh_c
# -1.0
# False
# DHBSH_1: 23dhbzs_c + h2o_c --> 23dhb_c + ser__L_c
# -1.0
# False
# DHBZS2H: 23dhbzs2_c + h2o_c --> 2.0 23dhbzs_c + h_c
# 1.0
# False
# DHBZS3H: 23dhbzs3_c + h2o_c --> 23dhbzs2_c + 23dhbzs_c + h_c
# 1.0
# False
# DHGLYH: dhgly_c + h2o_c + h_c --> glx_c + nh4_c
# -1.0
# False
# DHPM2: 56dthm_c + h2o_c --> 3uib_c + h_c
# 1.0
# False
# DNMPPA: dhpmp_c + h2o_c --> dhnpt_c + pi_c
# -2.0
# False
# DNTPPA: ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c
# 2.0
# False
# DRPA: 2dr5p_c --> acald_c + g3p_c
# 2.0
# False
# DURIPP: duri_c + pi_c <=> 2dr1p_c + ura_c
# 2.0
# False
# DURIPP_1: duri_c + pi_c <=> 2dr1p_c + ura_c
# 2.0
# False
# DXPRIi: dxyl5p_c + h_c + nadph_c --> 2me4p_c + nadp_c
# 2.0
# False
# DXPS: g3p_c + h_c + pyr_c --> co2_c + dxyl5p_c
# -2.0
# False
# ECOAH1_1: 3hbycoa_c <=> b2coa_c + h2o_c
# -4.0
# False
# ECOAH5_1: 3hddcoa_c <=> h2o_c + trans_dd2coa_c
# 4.0
# False
# ECOAH6: 3htdcoa_c <=> h2o_c + td2coa_c
# 4.0
# False
# ECOAH8: 3hodcoa_c <=> h2o_c + od2coa_c
# -4.0
# False
# EDA: 2ddg6p_c --> g3p_c + pyr_c
# 2.0
# False
# ENTERES: enter_c + 3.0 h2o_c --> 3.0 23dhbzs_c + 2.0 h_c
# 3.0
# False
# ENTERES2: feenter_c + 3.0 h2o_c --> 3.0 23dhbzs_c + fe3_c + 2.0 h_c
# 5.0
# False
# ENTERH: enter_c + h2o_c --> 23dhbzs3_c
# 1.0
# False
# F6PA: f6p_c <=> dha_c + g3p_c
# 2.0
# False
# FA80ACPHi: h2o_c + ocACP_c --> ACP_c + h_c + octa_c
# 2.0
# False
# FACOAL141t2pp: atp_c + coa_c + h_p + ttdcea_p --> amp_c + h_c + ppi_c + tdecoa_c
# 4.0
# False
# FACOAL50t2pp: atp_c + coa_c + h_p + pta_p --> amp_c + h_c + ppi_c + ptcoa_c
# 4.0
# False
# FASC141ACP: ddcaACP_c + 2.0 h_c + malACP_c + nadph_c --> ACP_c + co2_c + h2o_c + nadp_c + tdeACP_c
# -1.0
# False
# FBA: fdp_c <=> dhap_c + g3p_c
# -2.0
# False
# FBA3: s17bp_c <=> dhap_c + e4p_c
# -4.0
# False
# FBP: fdp_c + h2o_c --> f6p_c + pi_c
# -4.0
# False
# FCLPA: fc1p_c <=> dhap_c + lald__L_c
# -2.0
# False
# FCLT2: fmcbtt_c + ppp9_c --> 2.0 h_c + mcbtt_c + pheme_c
# 2.0
# False
# FE3DCITCH: 2.0 cit_c + fe3_c <=> fe3dcit_c
# 3.0
# False
# FE3DCITabcpp: atp_c + fe3dcit_p + h2o_c --> adp_c + 2.0 cit_c + fe3_c + h_c + pi_c
# -3.0
# False
# FE3PYOVDDR2: 2.0 fe3pyovd_kt_p + pqqh2_p <=> 2.0 fe2_p + 2.0 h_p + pqq_p + 2.0 pyovd_kt_p
# 10.0
# False
# FE3PYOVDL2: fe3_e + pyovd_kt_e <=> fe3pyovd_kt_e
# -3.0
# False
# FEDHBZS3R1: fadh2_c + 2.0 fe3dhbzs3_c --> 2.0 23dhbzs3_c + fad_c + 2.0 fe2_c + 4.0 h_c
# 8.0
# False
# FEDHBZS3R2: 2.0 fe3dhbzs3_c + fmnh2_c --> 2.0 23dhbzs3_c + 2.0 fe2_c + fmn_c + 4.0 h_c
# 8.0
# False
# FEDHBZS3R3: 2.0 fe3dhbzs3_c + rbflvrd_c --> 2.0 23dhbzs3_c + 2.0 fe2_c + 4.0 h_c + ribflv_c
# 8.0
# False
# FEENTERES: feenter_c + h2o_c + h_c --> fe3dhbzs3_c
# -1.0
# False
# FEENTERR1: fadh2_c + 2.0 feenter_c --> 2.0 enter_c + fad_c + 2.0 fe2_c + 2.0 h_c
# 4.0
# False
# FEENTERR2: 2.0 feenter_c + fmnh2_c --> 2.0 enter_c + 2.0 fe2_c + fmn_c + 2.0 h_c
# 4.0
# False
# FEENTERR3: 2.0 feenter_c + rbflvrd_c --> 2.0 enter_c + 2.0 fe2_c + 2.0 h_c + ribflv_c
# 4.0
# False
# FETRANS: fmcbtt_c <=> fe2_c + mcbtt_c
# 2.0
# False
# FFSD: h2o_c + suc6p_c --> fru_c + g6p_c
# -2.0
# False
# FPRA: fdxrd_c + h_c + nadp_c --> fdxox_c + nadph_c
# -1.0
# False
# FRUK: atp_c + f1p_c --> adp_c + fdp_c + h_c
# 4.0
# False
# FUCpts: fuc_e + pep_c --> fc1p_c + pyr_c
# 2.0
# False
# G1PACT: accoa_c + gam1p_c --> acgam1p_c + coa_c + h_c
# 2.0
# False
# G3PAT120: ddcaACP_c + glyc3p_c --> 1ddecg3p_c + ACP_c
# 1.0
# False
# G3PAT141: glyc3p_c + tdeACP_c --> 1tdec7eg3p_c + ACP_c
# 2.0
# False
# G3PAT161: glyc3p_c + hdeACP_c --> 1hdec9eg3p_c + ACP_c
# 4.0
# False
# GALCTD_1: galctr__D_c --> 5d4dglcr_c + h2o_c
# -2.0
# False
# GAPD: g3p_c + nad_c + pi_c <=> 13dpg_c + h_c + nadh_c
# -2.0
# False
# GAPDi_nadp: 13dpg_c + h_c + nadph_c --> g3p_c + nadp_c + pi_c
# 2.0
# False
# GARFT: 10fthf_c + gar_c <=> fgam_c + h_c + thf_c
# 2.0
# False
# GCCa: gly_c + h_c + lpro_c --> alpro_c + co2_c
# -1.0
# False
# GCCa_1: gcvhlipl_c + gly_c + h_c --> co2_c + gcvHalip_c
# -1.0
# False
# GCCb: alpro_c + thf_c --> dhlpro_c + mlthf_c + nh4_c
# 1.0
# False
# GCCb_1: gcvHalip_c + thf_c --> gcvHdhlip_c + mlthf_c + nh4_c
# 1.0
# False
# GCVHADPr: gcvHL_nhLA_c + nad_c --> gcvHL_ADPr_c + ncam_c
# 1.0
# False
# GCVHRADPr: gcvHL_ADPr_c + h2o_c --> adprib_c + gcvHL_nhLA_c + h_c
# -1.0
# False
# GD3P2: g3p_c + h2o_c + nadp_c --> 3pg_c + 2.0 h_c + nadph_c
# -2.0
# False
# GDPDPK: atp_c + gdp_c --> amp_c + h_c + ppgpp_c
# 6.0
# False
# GDPMANNDH: gdpmann_c + h2o_c + 2.0 nad_c --> gdpmanur_c + 3.0 h_c + 2.0 nadh_c
# 3.0
# False
# GDPTPDP: gdptp_c + h2o_c --> gtp_c + ppi_c
# -7.0
# False
# GG15DAPAH: ggaptn_c + h2o_c --> 5aptn_c + glu__L_c
# -1.0
# False
# GG15DAPDxr: ggbdapal_c + h2o_c + nad_c <=> ggaptn_c + 2.0 h_c + nadh_c
# 1.0
# False
# GG15DAPO: gg15dap_c + h2o_c + o2_c --> ggbdapal_c + h2o2_c + nh4_c
# 1.0
# False
# GG15DAPS: 15dap_c + atp_c + glu__L_c --> adp_c + gg15dap_c + h_c + pi_c
# -1.0
# False
# GGDAPAH: ggala_B_c + h2o_c --> ala_B_c + glu__L_c
# -1.0
# False
# GGDAPDxr: ggbamppal_c + h2o_c + nad_c <=> ggala_B_c + 2.0 h_c + nadh_c
# 1.0
# False
# GGDAPO: gg13dampp_c + h2o_c + o2_c --> ggbamppal_c + h2o2_c + nh4_c
# 1.0
# False
# GGDAPS: 13dampp_c + atp_c + glu__L_c --> adp_c + gg13dampp_c + h_c + pi_c
# -1.0
# False
# GGLUCT2: gluala_c --> 5oxpro_c + ala__L_c
# -1.0
# False
# GGSPMDO: ggspmd_c + h2o_c + o2_c --> 13dampp_c + ggbutal_c + h2o2_c
# 2.0
# False
# GGSPMDS: atp_c + glu__L_c + spmd_c --> adp_c + ggspmd_c + h_c + pi_c
# -2.0
# False
# GLCOASYNT: S_gtrdhdlp_c + coa_c <=> dhlam_c + glutcoa_c
# -1.0
# False
# GLCURS1: h2o_c + xylan4_c <=> glcur_c + xyl4_c
# -1.0
# False
# GLTPD: galt1p_c + nad_c <=> h_c + nadh_c + tag6p__D_c
# 2.0
# False
# GLUFT: 5fthf_c + glu__L_c --> Nforglu_c + thf_c
# 1.0
# False
# GLUTRR: glutrna_c + h_c + nadph_c --> glu1sa_c + nadp_c + trnaglu_c
# -3.0
# False
# GLUTRS: atp_c + glu__L_c + trnaglu_c --> amp_c + glutrna_c + ppi_c
# 3.0
# False
# GLUTRS_3: atp_c + glu__L_c + trnaglu_c --> amp_c + glutrna_c + ppi_c
# 3.0
# False
# GLYCS_I: gthrd_c + mthgxl_c --> lgt_s_c
# 1.0
# False
# GLYCS_II: h2o_c + lgt_s_c --> gthrd_c + h_c + lac__L_c
# -1.0
# False
# GLYCYSAP: gly_cys_c + h2o_c <=> cys__L_c + gly_c + h_c
# 1.0
# False
# GLYCYSabc: atp_c + gly_cys_e + h2o_c --> adp_c + gly_cys_c + pi_c
# -1.0
# False
# GLYLEUAP: gly_leu_c + h2o_c <=> gly_c + h_c + leu__L_c
# 1.0
# False
# GLYLEUtr: atp_c + gly_leu_e + h2o_c --> adp_c + gly_leu_c + pi_c
# -1.0
# False
# GLYPHEAP: gly_phe_c + h2o_c <=> gly_c + h_c + phe__L_c
# 1.0
# False
# GLYPHEtr: atp_c + gly_phe_e + h2o_c --> adp_c + gly_phe_c + pi_c
# -1.0
# False
# GLYTYRAP: gly_tyr_c + h2o_c <=> gly_c + h_c + tyr__L_c
# 1.0
# False
# GLYTYRabc: atp_c + gly_tyr_e + h2o_c --> adp_c + gly_tyr_c + pi_c
# -1.0
# False
# GPDDA2_1: g3pg_e + h2o_e --> glyc3p_e + glyc_e + h_e
# -1.0
# False
# GPDDA4: g3pg_c + h2o_c --> glyc3p_c + glyc_c + h_c
# -1.0
# False
# GPDDA4_1: g3pg_e + h2o_c --> glyc3p_c + glyc_c + h_c
# -1.0
# False
# GTMLT: ala__L_c + gthrd_c --> cgly_c + gluala_c
# 1.0
# False
# GTPDPK: atp_c + gtp_c --> amp_c + gdptp_c + h_c
# 7.0
# False
# GUI1: glcur_c <=> fruur_c
# 1.0
# False
# GUI2: galur_c <=> tagur_c
# 1.0
# False
# H2CD: h2isocapcoa_c + h_c --> h2o_c + isocaprecoa_c
# -1.0
# False
# H2CT: coa_c + h2isocap_c --> h2isocapcoa_c + h2o_c
# 4.0
# False
# HACD1_1: aacoa_c + h_c + nadh_c <=> 3hbycoa_c + nad_c
# 4.0
# False
# HACD3: 3oocoa_c + h_c + nadh_c <=> 3hocoa_c + nad_c
# 4.0
# False
# HACD9: 3hmbcoa_c + nad_c <=> 2maacoa_c + h_c + nadh_c
# 4.0
# False
# HACOADr: 3hmp_c + nad_c --> h_c + mmalsa__S_c + nadh_c
# 1.0
# False
# HBCHLR: 3hbcoa__R_c <=> b2coa_c + h2o_c
# -4.0
# False
# HEMEOS: frdp_c + h2o_c + pheme_c --> hemeO_c + ppi_c
# 2.0
# False
# HIUH_c: 5hiu_c + h2o_c <=> 5houdic_c
# -1.0
# False
# HMEDR: 2.0 h_c + hmbpp_c + nadh_c --> h2o_c + ipdp_c + nad_c
# -4.0
# False
# HMEDS: 2mecdp_c + 2.0 fdxrd_c --> 2.0 fdxox_c + h2o_c + hmbpp_c
# 4.0
# False
# HMR_6515: mercppyr_c + so3_c --> pyr_c + tsul_c
# 2.0
# False
# IBHH: 2mbald_c + nadh_c <=> h_c + ibtol_c + nad_c
# 2.0
# False
# ICCT: h2o_c + isocapcoa_c --> coa_c + h_c + isocap_c
# -3.0
# False
# ICHORT: h2o_c + ichor_c --> 23ddhb_c + pyr_c
# 1.0
# False
# ID6P: f6p_c + itp_c --> fdp_c + h_c + idp_c
# 4.0
# False
# IPDPUDCT: ggdp_c + h_c + 7.0 ipdp_c --> 7.0 ppi_c + udcpdp_c
# 2.0
# False
# IT6PT: itp_c + tag6p__D_c --> h_c + idp_c + tagdp__D_c
# 2.0
# False
# KARA2: 2ahbut_c + h_c + nadph_c <=> 23dhmp_c + nadp_c
# -1.0
# False
# KARI_1: 2ahbut_c --> 3hmop_c
# -1.0
# False
# KAT33: 3oxptcoa_c + coa_c --> accoa_c + ppcoa_c
# -4.0
# False
# LPLIPAL2G141: 2agpg141_c + h2o_c --> g3pg_c + h_c + ttdcea_c
# 1.0
# False
# MACCOAT: 2maacoa_c + coa_c --> accoa_c + ppcoa_c
# -4.0
# False
# MAN1PT: gtp_c + h_c + man1p_c --> gdpmann_c + ppi_c
# -2.0
# False
# MAN1PT2: gdp_c + h_c + man1p_c --> gdpmann_c + pi_c
# -2.0
# False
# MAN6PI: man6p_c <=> f6p_c
# -2.0
# False
# MCCC: 3mb2coa_c + atp_c + hco3_c --> 3mgcoa_c + adp_c + h_c + pi_c
# 5.0
# False
# MCTC_1: 3mb2coa_c + atp_c + hco3_c --> 3mgcoa_c + adp_c + h_c + pi_c
# 5.0
# False
# MCTP1App: murein5p5p_p --> ala__D_p + murein5px4p_p
# 4.0
# False
# MCTP2App: murein5p5p5p_p --> 2.0 ala__D_p + murein5px4px4p_p
# 6.0
# False
# MDDCP2pp: h2o_p + murein5px4px4p_p --> ala__D_p + murein4px4px4p_p
# -6.0
# False
# MDDEP1pp: h2o_p + murein4px4p_p --> murein4p4p_p
# -4.0
# False
# MDDEP3pp: h2o_p + murein5px4p_p --> murein5p4p_p
# -4.0
# False
# MECDPDH4E: 2mecdp_c + fdxrd_c + h_c <=> fdxo_2_2_c + h2mb4p_c + h2o_c
# -1.0
# False
# MEPCT: 2me4p_c + ctp_c + h_c --> 4c2me_c + ppi_c
# -2.0
# False
# MGCH: 3mgcoa_c + h2o_c <=> hmgcoa_c
# -5.0
# False
# MI3PP: h2o_c + mi3p__D_c --> inost_c + pi_c
# -2.0
# False
# MI3PS: g6p_c <=> mi3p__D_c
# 2.0
# False
# MLDCP1App: h2o_p + murein5px4p_p --> alaala_p + murein3px4p_p
# -4.0
# False
# MLDCP3App: h2o_p + murein5px3p_p --> alaala_p + murein3px3p_p
# 4.0
# False
# MLDEP1pp: h2o_p + murein3px3p_p --> murein3p3p_p
# -4.0
# False
# MLTGY2pp: murein4p3p_p --> anhgm3p_p + anhgm4p_p
# 2.0
# False
# MLTGY3pp: murein3p3p_p --> 2.0 anhgm3p_p
# 4.0
# False
# MLTGY4pp: murein4px4p4p_p --> anhgm4p_p + murein4px4p_p
# 4.0
# False
# MPTG: 2.0 uaagmda_c --> 2.0 h_c + murein5p5p_p + 2.0 udcpdp_c
# -2.0
# False
# MPTG2: murein5p5p_p + uaagmda_c --> h_c + murein5p5p5p_p + udcpdp_c
# -1.0
# False
# MS_1: hcys__L_c + mhpglu_c <=> hpglu_c + met__L_c
# -4.0
# False
# MUCCY_kt: CCbuttc_c + h_c --> 4cml_c
# 2.0
# False
# NADHHR: h2o_c + nadh_c --> nadhx__R_c
# 2.0
# False
# NADHXD: adp_c + nadhx__S_c --> amp_c + h_c + nadh_c + pi_c
# -2.0
# False
# NADPHHR: h2o_c + nadph_c --> nadphx__R_c
# 4.0
# False
# NADPHXD: adp_c + nadphx__S_c --> amp_c + h_c + nadph_c + pi_c
# -4.0
# False
# NFORGLUAH2: Nforglu_c + h2o_c --> for_c + glu__L_c + h_c
# -1.0
# False
# NPHS: sbzcoa_c --> coa_c + dhna_c
# -5.0
# False
# NTPTP1: dgtp_c + h2o_c --> dgsn_c + pppi_c
# 4.0
# False
# OXOADLR: 2oxoadp_c + h_c + lpam_c --> S_gtrdhdlp_c + co2_c
# 1.0
# False
# PALGSKT: 5.0 gdpmanur_c + h2o_c --> 5.0 gdp_c + 5.0 h_p + prealginate__M_p
# -10.0
# False
# PAPA120pp: h2o_p + pa120_p --> 12dgr120_p + pi_p
# -2.0
# False
# PAPA140pp: h2o_p + pa140_p --> 12dgr140_p + pi_p
# -2.0
# False
# PAPA141pp: h2o_p + pa141_p --> 12dgr141_p + pi_p
# -2.0
# False
# PAPA161pp: h2o_p + pa161_p --> 12dgr161_p + pi_p
# -2.0
# False
# PAPA180pp: h2o_p + pa180_p --> 12dgr180_p + pi_p
# -2.0
# False
# PAPA181pp: h2o_p + pa181_p --> 12dgr181_p + pi_p
# -2.0
# False
# PAPPT3: udcpp_c + ugmda_c --> uagmda_c + ump_c
# 3.0
# False
# PDBL_4: dhap_c + gln__L_c + r5p_c --> glu__L_c + 3.0 h2o_c + h_c + pi_c + pydx5p_c
# -2.0
# False
# PEAMNO2pp: h2o_p + peamn_p + pqq_p --> nh4_p + pacald_p + pqqh2_p
# -4.0
# False
# PEAOpp: h_p + pea_p + pqq_p --> pacald_p + pqqh2_p
# -5.0
# False
# PFK: atp_c + f6p_c --> adp_c + fdp_c + h_c
# 4.0
# False
# PFK_2: atp_c + tag6p__D_c --> adp_c + h_c + tagdp__D_c
# 2.0
# False
# PFK_3: atp_c + s7p_c --> adp_c + h_c + s17bp_c
# 4.0
# False
# PGI1c: g6p_A_c <=> f6p_c
# -2.0
# False
# PGPP120: h2o_c + pgp120_c --> pg120_c + pi_c
# -2.0
# False
# PGPP120pp: h2o_p + pgp120_p --> pg120_p + pi_p
# -2.0
# False
# PGPP140: h2o_c + pgp140_c --> pg140_c + pi_c
# -3.0
# False
# PGPP140pp: h2o_p + pgp140_p --> pg140_p + pi_p
# -3.0
# False
# PGPP141: h2o_c + pgp141_c --> pg141_c + pi_c
# -3.0
# False
# PGPP141pp: h2o_p + pgp141_p --> pg141_p + pi_p
# -3.0
# False
# PGPP160: h2o_c + pgp160_c --> pg160_c + pi_c
# -2.0
# False
# PGPP160pp: h2o_p + pgp160_p --> pg160_p + pi_p
# -2.0
# False
# PGPP161: h2o_c + pgp161_c --> pg161_c + pi_c
# -3.0
# False
# PGPP161pp: h2o_p + pgp161_p --> pg161_p + pi_p
# -3.0
# False
# PGPP180: h2o_c + pgp180_c --> pg180_c + pi_c
# -2.0
# False
# PGPP180pp: h2o_p + pgp180_p --> pg180_p + pi_p
# -2.0
# False
# PGPP181: h2o_c + pgp181_c --> pg181_c + pi_c
# -3.0
# False
# PGPP181pp: h2o_p + pgp181_p --> pg181_p + pi_p
# -3.0
# False
# PGSA120: cdpdddecg_c + glyc3p_c --> cmp_c + h_c + pgp120_c
# 3.0
# False
# PGSA140: cdpdtdecg_c + glyc3p_c --> cmp_c + h_c + pgp140_c
# 3.0
# False
# PGSA141: cdpdtdec7eg_c + glyc3p_c --> cmp_c + h_c + pgp141_c
# 3.0
# False
# PGSA160: cdpdhdecg_c + glyc3p_c --> cmp_c + h_c + pgp160_c
# 3.0
# False
# PGSA161: cdpdhdec9eg_c + glyc3p_c --> cmp_c + h_c + pgp161_c
# 3.0
# False
# PGSA180: cdpdodecg_c + glyc3p_c --> cmp_c + h_c + pgp180_c
# 3.0
# False
# PGSA181: cdpdodec11eg_c + glyc3p_c --> cmp_c + h_c + pgp181_c
# 3.0
# False
# PKETX: pi_c + xu5p__D_c --> actp_c + g3p_c + h2o_c
# 2.0
# False
# PLIPA1G160pp: h2o_p + pg160_p --> 2agpg160_p + h_p + hdca_p
# -1.0
# False
# PLIPA1G161pp: h2o_p + pg161_p --> 2agpg161_p + h_p + hdcea_p
# 1.0
# False
# PLPS: g3p_c + gln__L_c + r5p_c --> glu__L_c + 3.0 h2o_c + h_c + pi_c + pydx5p_c
# -4.0
# False
# PLPS_1: g3p_c + gln__L_c + ru5p__D_c --> glu__L_c + 3.0 h2o_c + h_c + pi_c + pydx5p_c
# -2.0
# False
# PPA2: h2o_c + pppi_c --> h_c + pi_c + ppi_c
# -4.0
# False
# PPGPPDP: h2o_c + ppgpp_c --> gdp_c + ppi_c
# -6.0
# False
# PPK2: atp_c + ppi_c --> adp_c + pppi_c
# 4.0
# False
# PPM: r1p_c <=> r5p_c
# 2.0
# False
# PPM2: 2dr1p_c <=> 2dr5p_c
# -2.0
# False
# PPND: nad_c + pphn_c --> 34hpp_c + co2_c + nadh_c
# -2.0
# False
# PPNDH: h_c + pphn_c --> co2_c + h2o_c + phpyr_c
# -2.0
# False
# PRAMPC: h2o_c + prbamp_c --> prfp_c
# -4.0
# False
# PRASCSi: 5aizc_c + asp__L_c + atp_c --> 25aics_c + adp_c + h_c + pi_c
# -3.0
# False
# PRATPP: h2o_c + prbatp_c --> h_c + ppi_c + prbamp_c
# -2.0
# False
# PROR: pro__L_c <=> h_c + pro__D_c
# 1.0
# False
# PRPPS: atp_c + r5p_c <=> amp_c + h_c + prpp_c
# -2.0
# False
# PSD120: h_c + ps120_c --> co2_c + pe120_c
# -1.0
# False
# PSD141: h_c + ps141_c --> co2_c + pe141_c
# -1.0
# False
# PSD161: h_c + ps161_c --> co2_c + pe161_c
# -1.0
# False
# PSSA120: cdpdddecg_c + ser__L_c --> cmp_c + h_c + ps120_c
# 1.0
# False
# PSSA141: cdpdtdec7eg_c + ser__L_c --> cmp_c + h_c + ps141_c
# 1.0
# False
# PSSA161: cdpdhdec9eg_c + ser__L_c --> cmp_c + h_c + ps161_c
# 1.0
# False
# PSUDS: r5p_c + ura_c --> h2o_c + psd5p_c
# -2.0
# False
# PTAILE: 2mbcoa_c + pi_c --> 2mb_p_c + coa_c
# 2.0
# False
# PUNP2: dad_2_c + pi_c <=> 2dr1p_c + ade_c
# 2.0
# False
# PUNP4: dgsn_c + pi_c <=> 2dr1p_c + gua_c
# 2.0
# False
# PUNP6: din_c + pi_c <=> 2dr1p_c + hxan_c
# 2.0
# False
# PYDXS: g3p_c + gln__L_c + ru5p__D_c <=> glu__L_c + 3.0 h2o_c + h_c + pi_c + pydx5p_c
# -2.0
# False
# QSDH: pqq_c + skm_c <=> 3dhsk_c + pqqh2_c
# -4.0
# False
# QUIDH: pqq_c + quin_c <=> 3dhq_c + pqqh2_c
# -4.0
# False
# R1PI: 2dr1p_c + 2.0 h_c <=> d2rib1p_c
# -2.0
# False
# R5PP: h2o_c + r5p_c --> pi_c + rib__D_c
# -2.0
# False
# RBFK: atp_c + ribflv_c --> adp_c + fmn_c + h_c
# 2.0
# False
# RBFSa: 4r5au_c + db4p_c --> dmlz_c + 2.0 h2o_c + pi_c
# -2.0
# False
# RBK: atp_c + rib__D_c --> adp_c + h_c + r5p_c
# 2.0
# False
# RECOAH2: R_3hhcoa_c <=> h2o_c + hx2coa_c
# -4.0
# False
# RECOAH4: R_3hdcoa_c <=> dc2coa_c + h2o_c
# -4.0
# False
# RECOAH6: R_3hmrscoa_c <=> h2o_c + td2coa_c
# 4.0
# False
# RECOAH7: R_3hhdcoa_c <=> h2o_c + hdd2coa_c
# -4.0
# False
# RHACOAE100: R_3hdcoa_c + h2o_c --> R_3hdcaa_c + coa_c + h_c
# -3.0
# False
# RHACOAE120: R_3hddcoa_c + h2o_c --> R_3hdda_c + coa_c + h_c
# 1.0
# False
# RHACOAE121: R_3hcddec5ecoa_c + h2o_c --> R_3hdd5ea_c + coa_c + h_c
# -3.0
# False
# RHACOAE121d6: R_3hdd6coa_c + h2o_c --> R_3hdd6e_c + coa_c + h_c
# -3.0
# False
# RHACOAE140: R_3hmrscoa_c + h2o_c --> R_3httdca_c + coa_c + h_c
# 1.0
# False
# RHACOAE141: R_3hcmrs7ecoa_c + h2o_c --> R_3hcmrs7e_c + coa_c + h_c
# -3.0
# False
# RHACOAE141d5: R_3htd5coa_c + h2o_c --> R_3htd5e_c + coa_c + h_c
# -3.0
# False
# RHACOAE142: R_3htd58coa_c + h2o_c --> R_3htd58e_c + coa_c + h_c
# -3.0
# False
# RHACOAE160: R_3hhdcoa_c + h2o_c --> R_3hhdca_c + coa_c + h_c
# -3.0
# False
# RHACOAE50: R_3hptcoa_c + h2o_c --> R_3hpt_c + coa_c + h_c
# -3.0
# False
# RHACOAE60: R_3hhcoa_c + h2o_c --> R_3hhxa_c + coa_c + h_c
# -3.0
# False
# RHACOAE70: R_3hhpcoa_c + h2o_c --> R_3hhpa_c + coa_c + h_c
# -3.0
# False
# RHACOAE80: R_3hocoa_c + h2o_c --> R_3hocta_c + coa_c + h_c
# -3.0
# False
# RHACOAE90: R_3hnonacoa_c + h2o_c --> R_3hnonaa_c + coa_c + h_c
# -3.0
# False
# RHACOAEP101: R3hdec4coa_c + h2o_c --> R3hdec4e_c + coa_c + h_c
# -3.0
# False
# RMK: atp_c + rml_c --> adp_c + h_c + rml1p_c
# 2.0
# False
# RMPA: rml1p_c <=> dhap_c + lald__L_c
# -2.0
# False
# RPI: r5p_c <=> ru5p__D_c
# -2.0
# False
# SALCHS1H: h2o_c + salchs1_c --> 23dhbzs_c + h_c + salchsx_c
# 1.0
# False
# SALCHS2FER1: fadh2_c + 2.0 salchs2fe_c --> fad_c + 2.0 fe2_c + 4.0 h_c + 2.0 salchs2_c
# 8.0
# False
# SALCHS2FER2: fmnh2_c + 2.0 salchs2fe_c --> 2.0 fe2_c + fmn_c + 4.0 h_c + 2.0 salchs2_c
# 8.0
# False
# SALCHS2FER3: rbflvrd_c + 2.0 salchs2fe_c --> 2.0 fe2_c + 4.0 h_c + ribflv_c + 2.0 salchs2_c
# 8.0
# False
# SALCHS4FER1: fadh2_c + 2.0 salchs4fe_c --> fad_c + 2.0 fe2_c + 4.0 h_c + 2.0 salchs4_c
# 8.0
# False
# SALCHS4FER2: fmnh2_c + 2.0 salchs4fe_c --> 2.0 fe2_c + fmn_c + 4.0 h_c + 2.0 salchs4_c
# 8.0
# False
# SALCHS4FER3: rbflvrd_c + 2.0 salchs4fe_c --> 2.0 fe2_c + 4.0 h_c + ribflv_c + 2.0 salchs4_c
# 8.0
# False
# SBP: h2o_c + s17bp_c --> pi_c + s7p_c
# -4.0
# False
# SCYSSL: 2.0 gthrd_c + scys__L_c --> cys__L_c + gthox_c + h_c + so3_c
# -1.0
# False
# SELADT: atp_c + h_c + sel_c --> adsel_c + ppi_c
# 2.0
# False
# SELCYSLY3: nadph_c + selcys_c --> ala__L_c + nadp_c + seln_c
# 1.0
# False
# SHCHF: fe2_c + scl_c --> 3.0 h_c + sheme_c
# -7.0
# False
# SHGO: S2hglut_c + o2_c --> akg_c + h2o2_c
# -2.0
# False
# SLCYSS: acser_c + tsul_c --> ac_c + scys__L_c
# -1.0
# False
# SPMS: ametam_c + ptrc_c --> 5mta_c + h_c + spmd_c
# 2.0
# False
# SUCBZL: atp_c + coa_c + sucbz_c --> amp_c + ppi_c + sbzcoa_c
# 5.0
# False
# SUCBZS: 2shchc_c --> h2o_c + sucbz_c
# -2.0
# False
# SUCpts: pep_c + sucr_e --> pyr_c + suc6p_c
# 2.0
# False
# T6PK: atp_c + tag6p__D_c --> adp_c + h_c + tagdp__D_c
# 2.0
# False
# TAGURr: altrn_c + nad_c <=> h_c + nadh_c + tagur_c
# 1.0
# False
# TALA: g3p_c + s7p_c <=> e4p_c + f6p_c
# -2.0
# False
# TETDHpp1: mql8_c + tet_p --> 2.0 h_p + mqn8_c + 2.0 tsul_p
# 4.0
# False
# TETDHpp2: 2dmmql8_c + tet_p --> 2dmmq8_c + 2.0 h_p + 2.0 tsul_p
# 4.0
# False
# TETDHpp3: q8h2_c + tet_p --> 2.0 h_p + q8_c + 2.0 tsul_p
# 4.0
# False
# TGBPA: tagdp__D_c <=> dhap_c + g3p_c
# -2.0
# False
# TKT2: e4p_c + xu5p__D_c <=> f6p_c + g3p_c
# 2.0
# False
# TMDPP: pi_c + thymd_c <=> 2dr1p_c + thym_c
# 2.0
# False
# TNTHAC1: 4hadnt_c + tntmdh_c --> 35dnta_c + h2o_c + no2_c
# -1.0
# False
# TNTHAC2: 2hadnt_c + tntmdh_c --> 2m35mdntha_c + h2o_c + no2_c
# -1.0
# False
# TNTR1: h_c + 2.0 nadph_c + tnt_c --> 4hadnt_c + h2o_c + 2.0 nadp_c
# 1.0
# False
# TNTR2: h_c + 2.0 nadph_c + tnt_c --> 2hadnt_c + h2o_c + 2.0 nadp_c
# 1.0
# False
# TPI: dhap_c <=> g3p_c
# 2.0
# False
# TRPS1: 3ig3p_c + ser__L_c --> g3p_c + h2o_c + trp__L_c
# 2.0
# False
# TRPS3: 3ig3p_c --> g3p_c + indole_c
# 2.0
# False
# TRPS3_1: 3ig3p_c --> g3p_c + ind_c
# 2.0
# False
# TSULR3e: 2.0 gthrd_c + tsul_c <-- gthox_c + h2s_c + so3_c
# -2.0
# False
# TTONR2pp: q8h2_c + tton_e --> 4.0 h_c + q8_c + so3_e + tsul_e
# 2.0
# False
# TYRL: amet_c + nadph_c + tyr__L_c --> 4crsol_c + dad_5_c + dhgly_c + h_c + met__L_c + nadp_c
# 1.0
# False
# UAG4Ei: uacgam_c <=> udpacgal_c
# 2.0
# False
# UAGDP: acgam1p_c + h_c + utp_c --> ppi_c + uacgam_c
# -2.0
# False
# UAGDP_1: acgam1p_c + h_c + utp_c --> ppi_c + uacgam_c
# -2.0
# False
# UAGHD: h_c + nadh_c + uaccg_c --> nad_c + uamr_c
# 3.0
# False
# UAMAS: ala__L_c + atp_c + uamr_c --> adp_c + h_c + pi_c + uama_c
# -3.0
# False
# UAPGR: h_c + nadph_c + uaccg_c --> nadp_c + uamr_c
# 3.0
# False
# UDCPDP: h2o_c + udcpdp_c --> h_c + pi_c + udcpp_c
# -2.0
# False
# UDCPDPS: frdp_c + h_c + 8.0 ipdp_c --> 8.0 ppi_c + udcpdp_c
# 2.0
# False
# UDCPDPex: h2o_e + udcpdp_e --> h_e + pi_e + udcpp_e
# -2.0
# False
# UM3PL: LalaDgluMdap_c + atp_c + uamr_c --> adp_c + h_c + pi_c + ugmd_c
# -3.0
# False
# UPP3MT: 2.0 amet_c + uppg3_c --> 2.0 ahcys_c + dscl_c + h_c
# 7.0
# False
# URO_c: h2o_c + o2_c + urate_c --> 5hiu_c + h2o2_c + h_c
# 1.0
# False
# UT6PT: tag6p__D_c + utp_c --> h_c + tagdp__D_c + udp_c
# 2.0
# False
# VOR2bE: 3mob_c + coa_c + fdxo_2_2_c --> co2_c + fdxrd_c + h_c + ibcoa_c
# 1.0
# False
# YUMPS: r5p_c + ura_c <=> h2o_c + psd5p_c
# -2.0
# False
# ilvg: 2obut_c + hethmpp_c --> 2ahbut_c + thmpp_c
# -1.0
# False
# r0191: f6p_c + utp_c --> fdp_c + h_c + udp_c
# 4.0
# False
# sink_mobd_c: mobd_c -->
# 2.0
# False
# sink_sheme_c: sheme_c -->
# 8.0
# False
# EX_3amp_e: 3amp_e <=>
# 2.0
# False
# EX_3cmp_e: 3cmp_e <=>
# 2.0
# False
# EX_3mb_e: 3mb_e <=>
# 1.0
# False
# EX_3ump_e: 3ump_e <=>
# 2.0
# False
# EX_4hbz_e: 4hbz_e <=>
# 1.0
# False
# EX_5mdru1p_e: 5mdru1p_e <=>
# 2.0
# False
# EX_Lcyst_e: Lcyst_e <=>
# 1.0
# False
# EX_ac_e: ac_e <=>
# 1.0
# False
# EX_akg_e: akg_e <=>
# 2.0
# False
# EX_ala_L_asp__L_e: ala_L_asp__L_e <=>
# 1.0
# False
# EX_arg__L_e: arg__L_e <=>
# -1.0
# False
# EX_aso4_e: aso4_e <=>
# 2.0
# False
# EX_asp__L_e: asp__L_e <=>
# 1.0
# False
# EX_but_e: but_e <=>
# 1.0
# False
# EX_butso3_e: butso3_e <=>
# 1.0
# False
# EX_bz_e: bz_e <=>
# 1.0
# False
# EX_ca2_e: ca2_e <=>
# -2.0
# False
# EX_chol_e: chol_e <=>
# -1.0
# False
# EX_cl_e: cl_e <=>
# 1.0
# False
# EX_cobalt2_e: cobalt2_e <=>
# -2.0
# False
# EX_cu2_e: cu2_e <=>
# -2.0
# False
# EX_dca_e: dca_e <=>
# 1.0
# False
# EX_enter_e: enter_e <=>
# 1.0
# False
# EX_etha_e: etha_e <=>
# -1.0
# False
# EX_ethso3_e: ethso3_e <=>
# 1.0
# False
# EX_fe2_e: fe2_e <=>
# -2.0
# False
# EX_fe3_e: fe3_e <=>
# -3.0
# False
# EX_for_e: for_e <=>
# 1.0
# False
# EX_fum_e: fum_e <=>
# 2.0
# False
# EX_g3ps_e: g3ps_e <=>
# 1.0
# False
# EX_galct__D_e: galct__D_e <=>
# 2.0
# False
# EX_galctn__D_e: galctn__D_e <=>
# 1.0
# False
# EX_galur_e: galur_e <=>
# 1.0
# False
# EX_glcr_e: glcr_e <=>
# 2.0
# False
# EX_glcur_e: glcur_e <=>
# 1.0
# False
# EX_glu__L_e: glu__L_e <=>
# 1.0
# False
# EX_glyc3p_e: glyc3p_e <=>
# 2.0
# False
# EX_glyc__R_e: glyc__R_e <=>
# 1.0
# False
# EX_glyclt_e: glyclt_e <=>
# 1.0
# False
# EX_gthrd_e: gthrd_e <=>
# 1.0
# False
# EX_h_e: h_e <=>
# -1.0
# False
# EX_hdca_e: hdca_e <=>
# 1.0
# False
# EX_hexs_e: hexs_e <=>
# 1.0
# False
# EX_hxa_e: hxa_e <=>
# 1.0
# False
# EX_ibt_e: ibt_e <=>
# 1.0
# False
# EX_ind3ac_e: ind3ac_e <=>
# 1.0
# False
# EX_isetac_e: isetac_e <=>
# 1.0
# False
# EX_k_e: k_e <=>
# -1.0
# False
# EX_lac__D_e: lac__D_e <=>
# 1.0
# False
# EX_lac__L_e: lac__L_e <=>
# 1.0
# False
# EX_lnlc_e: lnlc_e <=>
# 1.0
# False
# EX_mal__D_e: mal__D_e <=>
# 2.0
# False
# EX_mal__L_e: mal__L_e <=>
# 2.0
# False
# EX_mg2_e: mg2_e <=>
# -2.0
# False
# EX_mn2_e: mn2_e <=>
# -2.0
# False
# EX_mobd_e: mobd_e <=>
# 2.0
# False
# EX_mso3_e: mso3_e <=>
# 1.0
# False
# EX_nh4_e: nh4_e <=>
# -1.0
# False
# EX_no2_e: no2_e <=>
# 1.0
# False
# EX_no3_e: no3_e <=>
# 1.0
# False
# EX_oaa_e: oaa_e <=>
# 2.0
# False
# EX_ocdca_e: ocdca_e <=>
# 1.0
# False
# EX_ocdcea_e: ocdcea_e <=>
# 1.0
# False
# EX_octa_e: octa_e <=>
# 1.0
# False
# EX_orn_e: orn_e <=>
# -1.0
# False
# EX_orot_e: orot_e <=>
# 1.0
# False
# EX_oxa_e: oxa_e <=>
# 2.0
# False
# EX_peamn_e: peamn_e <=>
# -1.0
# False
# EX_pi_e: pi_e <=>
# 2.0
# False
# EX_pnto__R_e: pnto__R_e <=>
# 1.0
# False
# EX_ppa_e: ppa_e <=>
# 1.0
# False
# EX_pta_e: pta_e <=>
# 1.0
# False
# EX_ptrc_e: ptrc_e <=>
# -2.0
# False
# EX_pyr_e: pyr_e <=>
# 1.0
# False
# EX_sel_e: sel_e <=>
# 2.0
# False
# EX_slnt_e: slnt_e <=>
# 2.0
# False
# EX_so3_e: so3_e <=>
# 2.0
# False
# EX_so4_e: so4_e <=>
# 2.0
# False
# EX_spmd_e: spmd_e <=>
# -3.0
# False
# EX_succ_e: succ_e <=>
# 2.0
# False
# EX_sulfac_e: sulfac_e <=>
# 2.0
# False
# EX_tartr__L_e: tartr__L_e <=>
# 2.0
# False
# EX_tet_e: tet_e <=>
# 2.0
# False
# EX_udcpp_e: udcpp_e <=>
# 1.0
# False
# EX_vanlt_e: vanlt_e <=>
# 1.0
# False
# EX_zn2_e: zn2_e <=>
# -2.0
# False
# Growth: 0.000223 10fthf_c + 0.513689 ala__L_c + 0.000223 amet_c + 0.295792 arg__L_c + 0.241055 asn__L_c + 0.241055 asp__L_c + 54.124831 atp_c + 0.005205 ca2_c + 0.005205 cl_c + 0.000576 coa_c + 0.0001 cobalt2_c + 0.133508 ctp_c + 0.000709 cu2_c + 0.09158 cys__L_c + 0.026166 datp_c + 0.027017 dctp_c + 0.027017 dgtp_c + 0.026166 dttp_c + 0.000223 fad_c + 0.006715 fe2_c + 0.007808 fe3_c + 0.26316 gln__L_c + 0.26316 glu__L_c + 0.612638 gly_c + 0.215096 gtp_c + 48.601527 h2o_c + 0.094738 his__L_c + 0.290529 ile__L_c + 0.195193 k_c + 0.450531 leu__L_c + 0.343161 lys__L_c + 0.153686 met__L_c + 0.008675 mg2_c + 0.000223 mlthf_c + 0.000691 mn2_c + 0.0001 mql8_c + 0.001831 nad_c + 0.000447 nadp_c + 0.185265 phe__L_c + 0.221055 pro__L_c + 0.000223 pydx5p_c + 0.000223 ribflv_c + 0.215792 ser__L_c + 0.004338 so4_c + 0.000223 thf_c + 0.000223 thmpp_c + 0.253687 thr__L_c + 0.056843 trp__L_c + 0.137896 tyr__L_c + 0.1 uaagmda_c + 0.144104 utp_c + 0.423162 val__L_c + 0.000341 zn2_c --> 53.95 adp_c + 53.95 h_c + 53.945662 pi_c + 0.773903 ppi_c
# 0.40572400000003306
# False

# %%
for rxn in rxn_list:
    print(rxn)
    balance = defaultdict(int)
    for metabolite, coefficient in iteritems(rxn.metabolites):
        for element, amount in iteritems(metabolite.elements):
            balance[element] += coefficient * amount
    #print(balance.values)
    h_val = balance.pop('H')
    print(h_val)
    balance = rxn.check_mass_balance()
    print(balance)
    rxn.add_metabolites({model.model_in.h_p:-1}, combine= True)
    rxn.check_mass_balance()

    #if h_val == 1:
    #    rxn.add_metabolites({model.metabolites.h_p:1}, combine= True)
    
#model_in.reactions.SALCHS4FEabcpp.check_mass_balance()
#model.reactions.NO3t2pp.add_metabolites({model.metabolites.h_p:1}, combine= True)

# %%
import memote.support.annotation as annotation
overview = annotation.generate_component_annotation_overview(rxn_list, "metanetx")
overview

from importlib_resources import open_text
import memote.support.data

with open_text(
    memote.support.data, "met_id_shortlist.json", encoding="utf-8"
) as file_handle:
    METANETX_SHORTLIST = pd.read_json(file_handle)
# Out:
# [<Reaction 2AGPGAT160 at 0x2af9638adfd0>,
#  <Reaction 2AGPGAT161 at 0x2af9638adf98>,
#  <Reaction 2DDARAA at 0x2af9638bebe0>,
#  <Reaction 2MBALDH at 0x2af9638cabe0>,
#  <Reaction 2S6HCCi at 0x2af9638d20f0>,
#  <Reaction 3HAACOAT80 at 0x2af9638d8be0>,
#  <Reaction A6PAG at 0x2af9638b7470>,
#  <Reaction AACPS2 at 0x2af9638d8390>,
#  <Reaction AACPS4 at 0x2af9638d8908>,
#  <Reaction AACPS7 at 0x2af9638e3908>,
#  <Reaction AACPS9 at 0x2af9638ec358>,
#  <Reaction AALDH at 0x2af9638d8cf8>,
#  <Reaction ACACT5r_1 at 0x2af9639446d8>,
#  <Reaction ACACT6r_1 at 0x2af963944cc0>,
#  <Reaction ACGAMPM at 0x2af96396c438>,
#  <Reaction ACHBS at 0x2af96396c400>,
#  <Reaction ACKILE at 0x2af963973278>,
#  <Reaction ACLS_a at 0x2af96397b668>,
#  <Reaction ACLS_b at 0x2af963985198>,
#  <Reaction ACLS_d at 0x2af963985470>,
#  <Reaction ACLSa_1 at 0x2af963985cc0>,
#  <Reaction ACLSb_1 at 0x2af96398c0f0>,
#  <Reaction ACM6PH at 0x2af96398c0b8>,
#  <Reaction ACOAD3 at 0x2af9639a74e0>,
#  <Reaction ACOAD3f at 0x2af9639a79b0>,
#  <Reaction ACOAD4_1 at 0x2af9639a70f0>,
#  <Reaction ACOAD6 at 0x2af9639b72b0>,
#  <Reaction ACOAD6f at 0x2af9639b77b8>,
#  <Reaction ACP1_FMN at 0x2af9639d1828>,
#  <Reaction ACPPAT120 at 0x2af9639d1cc0>,
#  <Reaction ACPPAT141 at 0x2af9639d7ba8>,
#  <Reaction ACPPAT161 at 0x2af9639d7630>,
#  <Reaction ACSERHS at 0x2af9639e9ac8>,
#  <Reaction ACSERL at 0x2af9639f1160>,
#  <Reaction ACSPHAC100 at 0x2af9639e94e0>,
#  <Reaction ACSPHAC101 at 0x2af9639e9a58>,
#  <Reaction ACSPHAC120 at 0x2af9639f1128>,
#  <Reaction ACSPHAC121 at 0x2af9639f14a8>,
#  <Reaction ACSPHAC121d6 at 0x2af9639f1940>,
#  <Reaction ACSPHAC140 at 0x2af9639f1dd8>,
#  <Reaction ACSPHAC141 at 0x2af9639fe2b0>,
#  <Reaction ACSPHAC141d5 at 0x2af9639fe748>,
#  <Reaction ACSPHAC142 at 0x2af9639febe0>,
#  <Reaction ACSPHAC160 at 0x2af963a060b8>,
#  <Reaction ACSPHAC40 at 0x2af963a06550>,
#  <Reaction ACSPHAC50 at 0x2af963a069e8>,
#  <Reaction ACSPHAC60 at 0x2af963a06e80>,
#  <Reaction ACSPHAC70 at 0x2af963a10358>,
#  <Reaction ACSPHAC80 at 0x2af963a10828>,
#  <Reaction ACSPHAC90 at 0x2af963a10c88>,
#  <Reaction ADK2 at 0x2af963a47a20>,
#  <Reaction ADK2_1 at 0x2af963a520f0>,
#  <Reaction ADMDC at 0x2af963a52940>,
#  <Reaction ADPRDP at 0x2af963a62e48>,
#  <Reaction ADPRDP_1 at 0x2af963a62cc0>,
#  <Reaction ADSELK at 0x2af963a6d2e8>,
#  <Reaction ADSELR at 0x2af963a76278>,
#  <Reaction ADSL1r at 0x2af963a76208>,
#  <Reaction ADSS at 0x2af963a76748>,
#  <Reaction AGM3PA at 0x2af963a87748>,
#  <Reaction AGM3PApp at 0x2af963a7f780>,
#  <Reaction AGM3PH at 0x2af963a87da0>,
#  <Reaction AGM4PCPpp at 0x2af963a87dd8>,
#  <Reaction AGPAT120 at 0x2af963a98f60>,
#  <Reaction AGPAT141 at 0x2af963a98f28>,
#  <Reaction AGPAT161 at 0x2af963a98b38>,
#  <Reaction AHGDx at 0x2af963aaa390>,
#  <Reaction AHMMPDPT at 0x2af963aaaa20>,
#  <Reaction AHMMPS at 0x2af963ab2d68>,
#  <Reaction AHMMPS2 at 0x2af963abb208>,
#  <Reaction AHMMPS_1 at 0x2af963ab2518>,
#  <Reaction AHSERL4 at 0x2af963ac4940>,
#  <Reaction AIRC1 at 0x2af963acd080>,
#  <Reaction AIRC2 at 0x2af963acd588>,
#  <Reaction AIRC3 at 0x2af963acd6d8>,
#  <Reaction AIRCr at 0x2af963acdcc0>,
#  <Reaction AKGDa at 0x2af963ad7b00>,
#  <Reaction AKGDb at 0x2af963ad7dd8>,
#  <Reaction ALCDpp at 0x2af963b387b8>,
#  <Reaction ALDD4x at 0x2af963b4af98>,
#  <Reaction ALMPC at 0x2af963b5bfd0>,
#  <Reaction AMMQT8 at 0x2af963b95898>,
#  <Reaction AMPEP10 at 0x2af963b95b00>,
#  <Reaction AMPEP11 at 0x2af963b95be0>,
#  <Reaction AMPEP14 at 0x2af963ba70b8>,
#  <Reaction AMPEP15 at 0x2af963ba76d8>,
#  <Reaction AMPEP18 at 0x2af963ba7a20>,
#  <Reaction AMPEP5 at 0x2af963bba1d0>,
#  <Reaction AMPEP8 at 0x2af963bba6d8>,
#  <Reaction AMPMS2 at 0x2af963bbaa90>,
#  <Reaction ANHMK at 0x2af963bbacc0>,
#  <Reaction APG3PAT120 at 0x2af963bdbcc0>,
#  <Reaction APG3PAT141 at 0x2af963bdbd68>,
#  <Reaction APG3PAT161 at 0x2af963bdbb38>,
#  <Reaction APH120 at 0x2af963bea668>,
#  <Reaction APH141 at 0x2af963bea908>,
#  <Reaction APH161 at 0x2af963beaa90>,
#  <Reaction ARGSL at 0x2af963c0ada0>,
#  <Reaction ARGSS at 0x2af963c0af28>,
#  <Reaction ATPPRT at 0x2af963c5ffd0>,
#  <Reaction AT_MBD2 at 0x2af963c6e438>,
#  <Reaction BKDA2 at 0x2af963c6ee80>,
#  <Reaction BUP at 0x2af963c7cfd0>,
#  <Reaction CCPpp at 0x2af963ca9e48>,
#  <Reaction CD6P at 0x2af963ccaf98>,
#  <Reaction CDAPPA120 at 0x2af963cca7b8>,
#  <Reaction CDAPPA140 at 0x2af963ccae80>,
#  <Reaction CDAPPA141 at 0x2af963cd8b70>,
#  <Reaction CDAPPA161 at 0x2af963cd8978>,
#  <Reaction CDAPPA180 at 0x2af963cd8b00>,
#  <Reaction CDAPPA181 at 0x2af963cd85f8>,
#  <Reaction CDGUNPD at 0x2af963ce9ba8>,
#  <Reaction CHORM at 0x2af963cfc2b0>,
#  <Reaction CLPNH120pp at 0x2af963d0fc50>,
#  <Reaction CLPNH140pp at 0x2af963d0f8d0>,
#  <Reaction CLPNH141pp at 0x2af963d0ffd0>,
#  <Reaction CLPNH160pp at 0x2af963d17c18>,
#  <Reaction CLPNH161pp at 0x2af963d17d68>,
#  <Reaction CLPNH180pp at 0x2af963d17ef0>,
#  <Reaction CLPNH181pp at 0x2af963d2c0b8>,
#  <Reaction CLPNS120pp at 0x2af963d2c240>,
#  <Reaction CLPNS160pp at 0x2af963d2c588>,
#  <Reaction CLPNS180pp at 0x2af963d17ac8>,
#  <Reaction CMCBTFR1 at 0x2af963d2cac8>,
#  <Reaction CMLDC at 0x2af963d3dac8>,
#  <Reaction CO2FO at 0x2af963d3ddd8>,
#  <Reaction CPP3O1 at 0x2af963d71ac8>,
#  <Reaction CT6PT at 0x2af963d71f60>,
#  <Reaction CYO1b at 0x2af963d91d68>,
#  <Reaction CYO4pp at 0x2af963db15f8>,
#  <Reaction CYTCAA3pp at 0x2af963ddbe10>,
#  <Reaction CYTCBB3pp at 0x2af963ddb898>,
#  <Reaction D5KGK at 0x2af963e0a320>,
#  <Reaction D5KGPA at 0x2af963e2a278>,
#  <Reaction DACL at 0x2af963e0a9e8>,
#  <Reaction DAGK120 at 0x2af963e2a6a0>,
#  <Reaction DAGK140 at 0x2af963e347f0>,
#  <Reaction DAGK141 at 0x2af963e34710>,
#  <Reaction DAGK161 at 0x2af963e34eb8>,
#  <Reaction DAGK180 at 0x2af963e44128>,
#  <Reaction DAGK181 at 0x2af963e44358>,
#  <Reaction DASYN120 at 0x2af963e57828>,
#  <Reaction DASYN140 at 0x2af963e449e8>,
#  <Reaction DASYN141 at 0x2af963e57da0>,
#  <Reaction DASYN161 at 0x2af963e577b8>,
#  <Reaction DASYN180 at 0x2af963e57e10>,
#  <Reaction DASYN181 at 0x2af963e575c0>,
#  <Reaction DB4PS at 0x2af963e66710>,
#  <Reaction DDPGALA at 0x2af963e91208>,
#  <Reaction DGUNC at 0x2af963e91908>,
#  <Reaction DHBD at 0x2af963e91fd0>,
#  <Reaction DHBSH_1 at 0x2af963eaf358>,
#  <Reaction DHBZS2H at 0x2af963ea0dd8>,
#  <Reaction DHBZS3H at 0x2af963eaf630>,
#  <Reaction DHGLYH at 0x2af963ebf8d0>,
#  <Reaction DHPM2 at 0x2af963ebfbe0>,
#  <Reaction DNMPPA at 0x2af963f17898>,
#  <Reaction DNTPPA at 0x2af963f17c18>,
#  <Reaction DRPA at 0x2af963f27710>,
#  <Reaction DURIPP at 0x2af963f4f630>,
#  <Reaction DURIPP_1 at 0x2af963f35a20>,
#  <Reaction DXPRIi at 0x2af963f5d710>,
#  <Reaction DXPS at 0x2af963f5d470>,
#  <Reaction ECOAH1_1 at 0x2af963f69470>,
#  <Reaction ECOAH5_1 at 0x2af963f767b8>,
#  <Reaction ECOAH6 at 0x2af963f76e48>,
#  <Reaction ECOAH8 at 0x2af963f85a58>,
#  <Reaction EDA at 0x2af963f857f0>,
#  <Reaction ENTERES at 0x2af963f90da0>,
#  <Reaction ENTERES2 at 0x2af963f85fd0>,
#  <Reaction ENTERH at 0x2af963f9d438>,
#  <Reaction F6PA at 0x2af963f9def0>,
#  <Reaction FA80ACPHi at 0x2af963f9de80>,
#  <Reaction FACOAL141t2pp at 0x2af963fb96d8>,
#  <Reaction FACOAL50t2pp at 0x2af963fda4a8>,
#  <Reaction FASC141ACP at 0x2af964004cc0>,
#  <Reaction FBA at 0x2af964004e80>,
#  <Reaction FBA3 at 0x2af964004fd0>,
#  <Reaction FBP at 0x2af964016c18>,
#  <Reaction FCLPA at 0x2af964016c88>,
#  <Reaction FCLT2 at 0x2af96402c2b0>,
#  <Reaction FE3DCITCH at 0x2af964079ef0>,
#  <Reaction FE3DCITabcpp at 0x2af964079eb8>,
#  <Reaction FE3PYOVDDR2 at 0x2af96408a358>,
#  <Reaction FE3PYOVDL2 at 0x2af96408aa20>,
#  <Reaction FEDHBZS3R1 at 0x2af96408ae80>,
#  <Reaction FEDHBZS3R2 at 0x2af96409bac8>,
#  <Reaction FEDHBZS3R3 at 0x2af96409bda0>,
#  <Reaction FEENTERES at 0x2af96409bef0>,
#  <Reaction FEENTERR1 at 0x2af9640ad4a8>,
#  <Reaction FEENTERR2 at 0x2af9640ad6a0>,
#  <Reaction FEENTERR3 at 0x2af96409b860>,
#  <Reaction FETRANS at 0x2af9640cf3c8>,
#  <Reaction FFSD at 0x2af9640c4b38>,
#  <Reaction FPRA at 0x2af9640e4c50>,
#  <Reaction FRUK at 0x2af9640f0c88>,
#  <Reaction FUCpts at 0x2af9641082e8>,
#  <Reaction G1PACT at 0x2af964116a20>,
#  <Reaction G3PAT120 at 0x2af964108208>,
#  <Reaction G3PAT141 at 0x2af964116748>,
#  <Reaction G3PAT161 at 0x2af964116b38>,
#  <Reaction GALCTD_1 at 0x2af96412edd8>,
#  <Reaction GAPD at 0x2af964166c88>,
#  <Reaction GAPDi_nadp at 0x2af9641776a0>,
#  <Reaction GARFT at 0x2af964166b38>,
#  <Reaction GCCa at 0x2af964177a90>,
#  <Reaction GCCa_1 at 0x2af964185f60>,
#  <Reaction GCCb at 0x2af964185be0>,
#  <Reaction GCCb_1 at 0x2af964196518>,
#  <Reaction GCVHADPr at 0x2af964185ef0>,
#  <Reaction GCVHRADPr at 0x2af964185748>,
#  <Reaction GD3P2 at 0x2af9641851d0>,
#  <Reaction GDPDPK at 0x2af9641a4550>,
#  <Reaction GDPMANNDH at 0x2af964196ba8>,
#  <Reaction GDPTPDP at 0x2af9641a4e10>,
#  <Reaction GG15DAPAH at 0x2af9641a40b8>,
#  <Reaction GG15DAPDxr at 0x2af9641a49b0>,
#  <Reaction GG15DAPO at 0x2af9641a4d30>,
#  <Reaction GG15DAPS at 0x2af9641a4f28>,
#  <Reaction GGDAPAH at 0x2af9641b4ba8>,
#  <Reaction GGDAPDxr at 0x2af9641b4828>,
#  <Reaction GGDAPO at 0x2af9641b4f28>,
#  <Reaction GGDAPS at 0x2af9641b4438>,
#  <Reaction GGLUCT2 at 0x2af9641c9198>,
#  <Reaction GGSPMDO at 0x2af9641c9898>,
#  <Reaction GGSPMDS at 0x2af9641c9c50>,
#  <Reaction GLCOASYNT at 0x2af9641daf60>,
#  <Reaction GLCURS1 at 0x2af9641f8b38>,
#  <Reaction GLTPD at 0x2af9642178d0>,
#  <Reaction GLUFT at 0x2af964217f60>,
#  <Reaction GLUTRR at 0x2af96424d320>,
#  <Reaction GLUTRS at 0x2af96424d550>,
#  <Reaction GLUTRS_3 at 0x2af964241860>,
#  <Reaction GLYCS_I at 0x2af96427d9e8>,
#  <Reaction GLYCS_II at 0x2af96427da90>,
#  <Reaction GLYCYSAP at 0x2af96428af28>,
#  <Reaction GLYCYSabc at 0x2af96428ac88>,
#  <Reaction GLYLEUAP at 0x2af9642aba20>,
#  <Reaction GLYLEUtr at 0x2af964297c88>,
#  <Reaction GLYPHEAP at 0x2af9642bc320>,
#  <Reaction GLYPHEtr at 0x2af9642abd68>,
#  <Reaction GLYTYRAP at 0x2af9642bc6d8>,
#  <Reaction GLYTYRabc at 0x2af9642abda0>,
#  <Reaction GPDDA2_1 at 0x2af9642cd828>,
#  <Reaction GPDDA4 at 0x2af9642ed390>,
#  <Reaction GPDDA4_1 at 0x2af9642cda90>,
#  <Reaction GTMLT at 0x2af9643005f8>,
#  <Reaction GTPDPK at 0x2af96431abe0>,
#  <Reaction GUI1 at 0x2af96432de10>,
#  <Reaction GUI2 at 0x2af96432df28>,
#  <Reaction H2CD at 0x2af9643374e0>,
#  <Reaction H2CT at 0x2af964337f98>,
#  <Reaction HACD1_1 at 0x2af9643536d8>,
#  <Reaction HACD3 at 0x2af964353898>,
#  <Reaction HACD9 at 0x2af964353a20>,
#  <Reaction HACOADr at 0x2af964375c18>,
#  <Reaction HBCHLR at 0x2af964375c50>,
#  <Reaction HEMEOS at 0x2af9643901d0>,
#  <Reaction HIUH_c at 0x2af9643ac470>,
#  <Reaction HMEDR at 0x2af96439f710>,
#  <Reaction HMEDS at 0x2af9643ac4e0>,
#  <Reaction HMR_6515 at 0x2af9643ac908>,
#  <Reaction IBHH at 0x2af94e9b8898>,
#  <Reaction ICCT at 0x2af94e9b8ba8>,
#  <Reaction ICHORT at 0x2af94e9d5940>,
#  <Reaction ID6P at 0x2af94e9d52b0>,
#  <Reaction IPDPUDCT at 0x2af94ea08ef0>,
#  <Reaction IT6PT at 0x2af94ea1add8>,
#  <Reaction KARA2 at 0x2af94ea27f60>,
#  <Reaction KARI_1 at 0x2af94ea45550>,
#  <Reaction KAT33 at 0x2af94ea45cc0>,
#  <Reaction LPLIPAL2G141 at 0x2af94eac5128>,
#  <Reaction MACCOAT at 0x2af94eae5a20>,
#  <Reaction MAN1PT at 0x2af94eb009e8>,
#  <Reaction MAN1PT2 at 0x2af94eb0c3c8>,
#  <Reaction MAN6PI at 0x2af94eb0c7b8>,
#  <Reaction MCCC at 0x2af94eb0cd68>,
#  <Reaction MCTC_1 at 0x2af94eb28f28>,
#  <Reaction MCTP1App at 0x2af94eb1bb38>,
#  <Reaction MCTP2App at 0x2af94eb1b9e8>,
#  <Reaction MDDCP2pp at 0x2af94eb28b00>,
#  <Reaction MDDEP1pp at 0x2af94eb34b38>,
#  <Reaction MDDEP3pp at 0x2af94eb34e80>,
#  <Reaction MECDPDH4E at 0x2af94eb48f28>,
#  <Reaction MEPCT at 0x2af94eb5bb70>,
#  <Reaction MGCH at 0x2af94eb88d30>,
#  <Reaction MI3PP at 0x2af94eb96e48>,
#  <Reaction MI3PS at 0x2af94eba55f8>,
#  <Reaction MLDCP1App at 0x2af94eba5cc0>,
#  <Reaction MLDCP3App at 0x2af94ebb4e80>,
#  <Reaction MLDEP1pp at 0x2af94ebb4be0>,
#  <Reaction MLTGY2pp at 0x2af94ebc2e10>,
#  <Reaction MLTGY3pp at 0x2af94ebc2d68>,
#  <Reaction MLTGY4pp at 0x2af94ebc2fd0>,
#  <Reaction MPTG at 0x2af9643c1b38>,
#  <Reaction MPTG2 at 0x2af9643c1d68>,
#  <Reaction MS_1 at 0x2af9643c15f8>,
#  <Reaction MUCCY_kt at 0x2af9643d4f28>,
#  <Reaction NADHHR at 0x2af96441b4a8>,
#  <Reaction NADHXD at 0x2af96441bb00>,
#  <Reaction NADPHHR at 0x2af96442a278>,
#  <Reaction NADPHXD at 0x2af96442a780>,
#  <Reaction NFORGLUAH2 at 0x2af964458550>,
#  <Reaction NPHS at 0x2af9644bea58>,
#  <Reaction NTPTP1 at 0x2af96450ebe0>,
#  <Reaction OXOADLR at 0x2af9645754a8>,
#  <Reaction PALGSKT at 0x2af964594a90>,
#  <Reaction PAPA120pp at 0x2af964581f60>,
#  <Reaction PAPA140pp at 0x2af964581d68>,
#  <Reaction PAPA141pp at 0x2af964594c88>,
#  <Reaction PAPA161pp at 0x2af964594cc0>,
#  <Reaction PAPA180pp at 0x2af964594f60>,
#  <Reaction PAPA181pp at 0x2af9645a8780>,
#  <Reaction PAPPT3 at 0x2af9645a8898>,
#  <Reaction PDBL_4 at 0x2af9645cb0b8>,
#  <Reaction PEAMNO2pp at 0x2af9645ece48>,
#  <Reaction PEAOpp at 0x2af9646039b0>,
#  <Reaction PFK at 0x2af964603048>,
#  <Reaction PFK_2 at 0x2af964603a20>,
#  <Reaction PFK_3 at 0x2af964603128>,
#  <Reaction PGI1c at 0x2af964623e48>,
#  <Reaction PGPP120 at 0x2af964677240>,
#  <Reaction PGPP120pp at 0x2af964653e80>,
#  <Reaction PGPP140 at 0x2af964677588>,
#  <Reaction PGPP140pp at 0x2af964660eb8>,
#  <Reaction PGPP141 at 0x2af964677710>,
#  <Reaction PGPP141pp at 0x2af964660ba8>,
#  <Reaction PGPP160 at 0x2af964677a58>,
#  <Reaction PGPP160pp at 0x2af9646778d0>,
#  <Reaction PGPP161 at 0x2af96468c048>,
#  <Reaction PGPP161pp at 0x2af964677c18>,
#  <Reaction PGPP180 at 0x2af96468c400>,
#  <Reaction PGPP180pp at 0x2af964677dd8>,
#  <Reaction PGPP181 at 0x2af96468c5c0>,
#  <Reaction PGPP181pp at 0x2af964677f98>,
#  <Reaction PGSA120 at 0x2af96468c978>,
#  <Reaction PGSA140 at 0x2af96468c9b0>,
#  <Reaction PGSA141 at 0x2af96468cfd0>,
#  <Reaction PGSA160 at 0x2af96469f2e8>,
#  <Reaction PGSA161 at 0x2af96469f588>,
#  <Reaction PGSA180 at 0x2af96469f828>,
#  <Reaction PGSA181 at 0x2af96469fac8>,
#  <Reaction PKETX at 0x2af9646bb9e8>,
#  <Reaction PLIPA1G160pp at 0x2af9646dc278>,
#  <Reaction PLIPA1G161pp at 0x2af9646dc400>,
#  <Reaction PLPS at 0x2af9646dc898>,
#  <Reaction PLPS_1 at 0x2af9646dceb8>,
#  <Reaction PPA2 at 0x2af9646f2eb8>,
#  <Reaction PPGPPDP at 0x2af96471bf28>,
#  <Reaction PPK2 at 0x2af96470afd0>,
#  <Reaction PPM at 0x2af96470add8>,
#  <Reaction PPM2 at 0x2af96471bac8>,
#  <Reaction PPND at 0x2af964726da0>,
#  <Reaction PPNDH at 0x2af9647269b0>,
#  <Reaction PRAMPC at 0x2af964752b38>,
#  <Reaction PRASCSi at 0x2af96475e080>,
#  <Reaction PRATPP at 0x2af96475e588>,
#  <Reaction PROR at 0x2af96475ea90>,
#  <Reaction PRPPS at 0x2af96476cf60>,
#  <Reaction PSD120 at 0x2af96477f240>,
#  <Reaction PSD141 at 0x2af96477fa90>,
#  <Reaction PSD161 at 0x2af96477fbe0>,
#  <Reaction PSSA120 at 0x2af96478b7f0>,
#  <Reaction PSSA141 at 0x2af96478ba20>,
#  <Reaction PSSA161 at 0x2af96478bc18>,
#  <Reaction PSUDS at 0x2af96477f898>,
#  <Reaction PTAILE at 0x2af96479a518>,
#  <Reaction PUNP2 at 0x2af9647a8e48>,
#  <Reaction PUNP4 at 0x2af9647b4da0>,
#  <Reaction PUNP6 at 0x2af9647b4d68>,
#  <Reaction PYDXS at 0x2af9647ca898>,
#  <Reaction QSDH at 0x2af9647f5630>,
#  <Reaction QUIDH at 0x2af9647f5860>,
#  <Reaction R1PI at 0x2af9647f5cc0>,
#  <Reaction R5PP at 0x2af9647f5f60>,
#  <Reaction RBFK at 0x2af9648067f0>,
#  <Reaction RBFSa at 0x2af964806898>,
#  <Reaction RBK at 0x2af964806e80>,
#  <Reaction RECOAH2 at 0x2af964832240>,
#  <Reaction RECOAH4 at 0x2af964832cc0>,
#  <Reaction RECOAH6 at 0x2af964847128>,
#  <Reaction RECOAH7 at 0x2af964847198>,
#  <Reaction RHACOAE100 at 0x2af964847240>,
#  <Reaction RHACOAE120 at 0x2af9648473c8>,
#  <Reaction RHACOAE121 at 0x2af9648476d8>,
#  <Reaction RHACOAE121d6 at 0x2af964832fd0>,
#  <Reaction RHACOAE140 at 0x2af964847978>,
#  <Reaction RHACOAE141 at 0x2af964847b00>,
#  <Reaction RHACOAE141d5 at 0x2af964847c88>,
#  <Reaction RHACOAE142 at 0x2af964847e10>,
#  <Reaction RHACOAE160 at 0x2af964847f98>,
#  <Reaction RHACOAE50 at 0x2af964847e80>,
#  <Reaction RHACOAE60 at 0x2af9648582e8>,
#  <Reaction RHACOAE70 at 0x2af964858470>,
#  <Reaction RHACOAE80 at 0x2af9648585f8>,
#  <Reaction RHACOAE90 at 0x2af964858780>,
#  <Reaction RHACOAEP101 at 0x2af964858908>,
#  <Reaction RMK at 0x2af96486fa58>,
#  <Reaction RMPA at 0x2af96486fe80>,
#  <Reaction RPI at 0x2af96488df60>,
#  <Reaction SALCHS1H at 0x2af96489ce10>,
#  <Reaction SALCHS2FER1 at 0x2af96489cf28>,
#  <Reaction SALCHS2FER2 at 0x2af96488d048>,
#  <Reaction SALCHS2FER3 at 0x2af9648aaa90>,
#  <Reaction SALCHS4FER1 at 0x2af9648aac88>,
#  <Reaction SALCHS4FER2 at 0x2af9648bd1d0>,
#  <Reaction SALCHS4FER3 at 0x2af96489ccc0>,
#  <Reaction SBP at 0x2af9648d18d0>,
#  <Reaction SCYSSL at 0x2af9648e0780>,
#  <Reaction SELADT at 0x2af9648ef5c0>,
#  <Reaction SELCYSLY3 at 0x2af9648ef3c8>,
#  <Reaction SHCHF at 0x2af9648efc88>,
#  <Reaction SHGO at 0x2af9648fd7f0>,
#  <Reaction SLCYSS at 0x2af964924128>,
#  <Reaction SPMS at 0x2af964924f28>,
#  <Reaction SUCBZL at 0x2af962f256a0>,
#  <Reaction SUCBZS at 0x2af963890cf8>,
#  <Reaction SUCpts at 0x2af9638e3198>,
#  <Reaction T6PK at 0x2af963956e48>,
#  <Reaction TAGURr at 0x2af96398c390>,
#  <Reaction TALA at 0x2af963985208>,
#  <Reaction TETDHpp1 at 0x2af9639ae588>,
#  <Reaction TETDHpp2 at 0x2af9639ae6a0>,
#  <Reaction TETDHpp3 at 0x2af9639b7c18>,
#  <Reaction TGBPA at 0x2af9639bef28>,
#  <Reaction TKT2 at 0x2af963a2dd30>,
#  <Reaction TMDPP at 0x2af963a3fcf8>,
#  <Reaction TNTHAC1 at 0x2af963a6dbe0>,
#  <Reaction TNTHAC2 at 0x2af963a7f6d8>,
#  <Reaction TNTR1 at 0x2af963a76be0>,
#  <Reaction TNTR2 at 0x2af963a6db38>,
#  <Reaction TPI at 0x2af963a980f0>,
#  <Reaction TRPS1 at 0x2af963ad79b0>,
#  <Reaction TRPS3 at 0x2af963ae61d0>,
#  <Reaction TRPS3_1 at 0x2af963af8c18>,
#  <Reaction TSULR3e at 0x2af963b38518>,
#  <Reaction TTONR2pp at 0x2af96494c9b0>,
#  <Reaction TYRL at 0x2af964a3d278>,
#  <Reaction UAG4Ei at 0x2af964a5a4e0>,
#  <Reaction UAGDP at 0x2af964a5a4a8>,
#  <Reaction UAGDP_1 at 0x2af964a63160>,
#  <Reaction UAGHD at 0x2af964a5a588>,
#  <Reaction UAMAS at 0x2af964a63fd0>,
#  <Reaction UAPGR at 0x2af964a639e8>,
#  <Reaction UDCPDP at 0x2af964a72a20>,
#  <Reaction UDCPDPS at 0x2af964a72f28>,
#  <Reaction UDCPDPex at 0x2af964a72588>,
#  <Reaction UM3PL at 0x2af964a84ba8>,
#  <Reaction UPP3MT at 0x2af964a98be0>,
#  <Reaction URO_c at 0x2af964ace4a8>,
#  <Reaction UT6PT at 0x2af964acee48>,
#  <Reaction VOR2bE at 0x2af964af1668>,
#  <Reaction YUMPS at 0x2af964b28710>,
#  <Reaction ilvg at 0x2af964b3afd0>,
#  <Reaction r0191 at 0x2af964b458d0>,
#  <Reaction sink_mobd_c at 0x2af964b59828>,
#  <Reaction sink_sheme_c at 0x2af964b59a58>,
#  <Reaction EX_3amp_e at 0x2af964b64668>,
#  <Reaction EX_3cmp_e at 0x2af964b64780>,
#  <Reaction EX_3mb_e at 0x2af964b648d0>,
#  <Reaction EX_3ump_e at 0x2af964b649e8>,
#  <Reaction EX_4hbz_e at 0x2af964b64d30>,
#  <Reaction EX_5mdru1p_e at 0x2af964b6c080>,
#  <Reaction EX_Lcyst_e at 0x2af964b6c2b0>,
#  <Reaction EX_ac_e at 0x2af964b6c668>,
#  <Reaction EX_akg_e at 0x2af964b6cc18>,
#  <Reaction EX_ala_L_asp__L_e at 0x2af964b6cd30>,
#  <Reaction EX_arg__L_e at 0x2af964b78940>,
#  <Reaction EX_aso4_e at 0x2af964b78b70>,
#  <Reaction EX_asp__L_e at 0x2af964b78cc0>,
#  <Reaction EX_but_e at 0x2af964b78dd8>,
#  <Reaction EX_butso3_e at 0x2af964b78eb8>,
#  <Reaction EX_bz_e at 0x2af964b83160>,
#  <Reaction EX_ca2_e at 0x2af964b83128>,
#  <Reaction EX_chol_e at 0x2af964b835f8>,
#  <Reaction EX_cl_e at 0x2af964b83978>,
#  <Reaction EX_cobalt2_e at 0x2af964b83cc0>,
#  <Reaction EX_cu2_e at 0x2af964b83ef0>,
#  <Reaction EX_dca_e at 0x2af964b8d6d8>,
#  <Reaction EX_enter_e at 0x2af964b8deb8>,
#  <Reaction EX_etha_e at 0x2af964b8df98>,
#  <Reaction EX_ethso3_e at 0x2af964b97128>,
#  <Reaction EX_fe2_e at 0x2af964b97588>,
#  <Reaction EX_fe3_e at 0x2af964b97668>,
#  <Reaction EX_for_e at 0x2af964b97ac8>,
#  <Reaction EX_fum_e at 0x2af964b97d30>,
#  <Reaction EX_g3ps_e at 0x2af964ba10b8>,
#  <Reaction EX_galct__D_e at 0x2af964ba13c8>,
#  <Reaction EX_galctn__D_e at 0x2af964ba1518>,
#  <Reaction EX_galur_e at 0x2af964ba17f0>,
#  <Reaction EX_glcr_e at 0x2af964ba1a90>,
#  <Reaction EX_glcur_e at 0x2af964ba1b00>,
#  <Reaction EX_glu__L_e at 0x2af964ba1b70>,
#  <Reaction EX_glyc3p_e at 0x2af964baf630>,
#  <Reaction EX_glyc__R_e at 0x2af964baf6d8>,
#  <Reaction EX_glyclt_e at 0x2af964baf898>,
#  <Reaction EX_gthrd_e at 0x2af964bafa90>,
#  <Reaction EX_h_e at 0x2af964bbf0b8>,
#  <Reaction EX_hdca_e at 0x2af964baff98>,
#  <Reaction EX_hexs_e at 0x2af964bafeb8>,
#  <Reaction EX_hxa_e at 0x2af964bbf208>,
#  <Reaction EX_ibt_e at 0x2af964bbf2b0>,
#  <Reaction EX_ind3ac_e at 0x2af964bbf4a8>,
#  <Reaction EX_isetac_e at 0x2af964bbf550>,
#  <Reaction EX_k_e at 0x2af964bbf978>,
#  <Reaction EX_lac__D_e at 0x2af964bbf940>,
#  <Reaction EX_lac__L_e at 0x2af964bbf898>,
#  <Reaction EX_lnlc_e at 0x2af964bbfba8>,
#  <Reaction EX_mal__D_e at 0x2af964bbfe80>,
#  <Reaction EX_mal__L_e at 0x2af964bbfef0>,
#  <Reaction EX_mg2_e at 0x2af964bcf358>,
#  <Reaction EX_mn2_e at 0x2af964bcf390>,
#  <Reaction EX_mobd_e at 0x2af964bcf470>,
#  <Reaction EX_mso3_e at 0x2af964bcf400>,
#  <Reaction EX_nh4_e at 0x2af964bcf7b8>,
#  <Reaction EX_no2_e at 0x2af964bcf780>,
#  <Reaction EX_no3_e at 0x2af964bcf828>,
#  <Reaction EX_oaa_e at 0x2af964bcfb00>,
#  <Reaction EX_ocdca_e at 0x2af964bcfba8>,
#  <Reaction EX_ocdcea_e at 0x2af964bcfc88>,
#  <Reaction EX_octa_e at 0x2af964bcfd68>,
#  <Reaction EX_orn_e at 0x2af964bcfe10>,
#  <Reaction EX_orot_e at 0x2af964bcfdd8>,
#  <Reaction EX_oxa_e at 0x2af964bcfd30>,
#  <Reaction EX_peamn_e at 0x2af964be00b8>,
#  <Reaction EX_pi_e at 0x2af964be02b0>,
#  <Reaction EX_pnto__R_e at 0x2af964be0390>,
#  <Reaction EX_ppa_e at 0x2af964be0358>,
#  <Reaction EX_pta_e at 0x2af964be06a0>,
#  <Reaction EX_ptrc_e at 0x2af964be0710>,
#  <Reaction EX_pyr_e at 0x2af964be0780>,
#  <Reaction EX_sel_e at 0x2af964be0dd8>,
#  <Reaction EX_slnt_e at 0x2af964bf0128>,
#  <Reaction EX_so3_e at 0x2af964bf0320>,
#  <Reaction EX_so4_e at 0x2af964bf0278>,
#  <Reaction EX_spmd_e at 0x2af964bf0358>,
#  <Reaction EX_succ_e at 0x2af964bf0438>,
#  <Reaction EX_sulfac_e at 0x2af964bf06a0>,
#  <Reaction EX_tartr__L_e at 0x2af964bf0898>,
#  <Reaction EX_tet_e at 0x2af964bf09b0>,
#  <Reaction EX_udcpp_e at 0x2af964c021d0>,
#  <Reaction EX_vanlt_e at 0x2af964c025f8>,
#  <Reaction EX_zn2_e at 0x2af964c02940>,
#  <Reaction Growth at 0x2af964c02ba8>]
